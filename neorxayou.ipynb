# %%
# !pip install spacy_transformers
# !pip install -U spacy

# %%
import random
import json
import spacy
from spacy.tokens import DocBin
from sklearn.model_selection import train_test_split

# Données de base
noms = [
    "Jean Dupont",
    "Marie Lefèvre",
    "Pierre Martin",
    "Sophie Dubois",
    "Luc Durand",
    "Marie Martin",
    "Pierre Dubois",
    "Sophie Lambert",
    "Thomas Bernard",
    "Émilie Durand",
    "Nicolas Petit",
    "Camille Moreau",
    "François Leroy",
    "Julie Robert",
    "Antoine Richard",
    "Céline Simon",
    "Michel Laurent",
    "Nathalie Lefebvre",
    "Alexandre Girard",
    "Isabelle Fontaine",
    "Olivier Rousseau",
    "Audrey Mercier",
    "Philippe Blanc",
    "Stéphanie Vincent",
    "Éric Bonnet",
    "Aurélie Fournier",
    "Julien Guerin",
    "Sandrine Meyer",
    "Pascal Garnier",
    "Claire Fabre",
    "Frédéric Denis",
    "Véronique Chevalier",
    "David Lemaire",
    "Caroline Bertrand",
    "Sébastien Robin",
    "Laurence Roy",
    "Christophe Morel",
    "Sylvie Legrand",
    "Thierry Gauthier",
    "Valérie Lucas",
    "Benoît Perrin",
    "Delphine Colin",
    "Laurent Vidal",
    "Christine Caron",
    "Yves Brun",
    "Martine Gérard",
    "Alain Barbier",
    "Laetitia Brunet",
    "Gilles Arnaud",
    "Catherine Picard",
    "Bruno Leclercq",
    "Florence Schmitt",
    "Jérôme Rolland",
    "Anne Meunier",
    "Patrick Masson",
    "Monique Dufour",
    "Didier Costa",
    "Virginie Mathieu",
    "Gérard Noel",
    "Mireille Joly",
    "Hervé Marchand",
    "Brigitte Poirier",
    "Emmanuel Henry",
    "Cécile Roux",
    "Christian Bourgeois",
    "Chantal Lemoine",
    "Bernard Marty",
    "Corinne Renard",
    "Joël Bouchard",
    "Françoise Benoit",
    "Dominique Perrier",
    "Josiane Cousin",
    "Claude Bouchet",
    "Jacqueline Hubert",
    "Louis Guillot",
    "Véronique Baron",
    "Georges Blanchard",
    "Ghislaine Rey",
    "Guy Fleury",
    "Pascale Lacroix",
    "Maurice Huet",
    "Élisabeth Jacquet",
    "Roger Mallet",
    "Andrée Bouvier",
    "André Berger",
    "Nicole Collet",
    "Jacques Aubry",
    "Danielle Royer",
    "Marc Schneider",
    "Simone Guyot",
    "Paul Léger",
    "Michèle Poulain",
    "Serge Charpentier",
    "Yvette Germain",
    "Henri Martinez",
    "Paulette Lebrun",
    "René Thibault",
    "Yvonne Besson",
    "Daniel Roche",
    "Lucette Garcia",
    "Robert Breton",
    "Jeannine Leclerc",
    "Raymond Pelletier",
    "Madeleine Roussel",
    "Mathieu Duval",
    "Sarah Giraud",
    "Guillaume Lefevre",
    "Charlotte Morin",
    "Étienne Boulanger",
    "Amélie Carpentier",
    "Romain Gautier",
    "Pauline Nguyen",
    "Maxime Leroux",
    "Justine Lacombe",
    "Adrien Aubert",
    "Anaïs Faure",
    "Kevin Renault",
    "Marion Lemoine",
    "Baptiste Deschamps",
    "Élodie Pichon",
    "Quentin Muller",
    "Eléonore Maillard",
    "Fabien Gallet",
    "Narbonne",
    "Nîmes",
    "Niort",
    "Orléans",
    "Pantin",
    "Pau",
    "Perpignan",
    "Pessac",
    "Poitiers",
    "Quimper",
    "Reims",
    "Rennes",
    "Roubaix",
    "Rouen",
    "Saint-Denis",
    "Saint-Étienne",
    "Saint-Malo",
    "Saint-Nazaire",
    "Saint-Quentin",
    "Strasbourg",
    "Tarbes",
    "Toulon",
    "Tourcoing",
    "Tours",
    "Troyes",
    "Valence",
    "Vannes",
    "Vénissieux",
    "Versailles",
    "Vienne",
    "Villeurbanne",
    "Vitry-sur-Seine",
    "Aix-les-Bains",
    "Albi",
    "Alès",
    "Arles",
    "Bastia",
    "Belfort",
    "Bergerac",
    "Biarritz",
    "Brive-la-Gaillarde",
    "Châteauroux",
    "Cherbourg",
    "Laval",
    "Mérignac"
]
formations = [
    "Master en Informatique",
    "Licence en Gestion",
    "BTS Comptabilité",
    "Doctorat en Biologie",
    "Master en Intelligence Artificielle",
    "Master en Cybersécurité",
    "Master en Science des Données",
    "Master en Génie Électrique",
    "Master en Génie Civil",
    "Master en Génie Mécanique",
    "Master en Robotique",
    "Master en Télécommunications",
    "Master en Biotechnologies",
    "Master en Chimie",
    "Master en Physique",
    "Master en Mathématiques Appliquées",
    "Master en Sciences de l'Environnement",
    "Master en Santé Publique",
    "Master en Neurosciences",
    "Master en Biologie Médicale",
    "Master en Psychologie Clinique",
    "Master en Sciences Infirmières",
    "Master en Nutrition",
    "Master en Psychologie",
    "Master en Sociologie",
    "Master en Histoire",
    "Master en Géographie",
    "Master en Sciences Politiques",
    "Master en Relations Internationales",
    "Master en Économie",
    "Master en Finance",
    "Master en Marketing",
    "Master en Management",
    "Master en Ressources Humaines",
    "Master en Droit",
    "Master en Criminologie",
    "Master en Littérature",
    "Master en Langues Étrangères Appliquées",
    "Master en Traduction",
    "Master en Arts Visuels",
    "Master en Cinéma",
    "Master en Musicologie",
    "Master en Architecture",
    "Master en Design",
    "Licence en Informatique",
    "Licence en Mathématiques",
    "Licence en Physique",
    "Licence en Chimie",
    "Licence en Biologie",
    "Licence en Sciences pour l'Ingénieur",
    "Licence en Sciences de la Terre",
    "Licence en Sciences de la Vie",
    "Licence en Sciences pour la Santé",
    "Licence en Psychologie",
    "Licence en Sciences Infirmières",
    "Licence en Droit",
    "Licence en Économie",
    "Licence en Sociologie",
    "Licence en Histoire",
    "Licence en Géographie",
    "Licence en Sciences Politiques",
    "Licence en Philosophie",
    "Licence en Sciences de l'Éducation",
    "Licence en Lettres Modernes",
    "Licence en Langues Étrangères",
    "Licence en Arts du Spectacle",
    "Licence en Arts Plastiques",
    "Licence en Musicologie",
    "Licence en Information-Communication",
    "BTS Systèmes Numériques",
    "BTS Services Informatiques aux Organisations",
    "BTS Maintenance des Systèmes",
    "BTS Électrotechnique",
    "BTS Bâtiment",
    "BTS Travaux Publics",
    "BTS Conception et Réalisation de Systèmes Automatiques",
    "BTS Management Commercial Opérationnel",
    "BTS Négociation et Digitalisation de la Relation Client",
    "BTS Gestion de la PME",
    "BTS Support à l'Action Managériale",
    "BTS Commerce International",
    "BTS Banque",
    "BTS Agricole",
    "BTS Aménagements Paysagers",
    "BTS Gestion et Protection de la Nature",
    "BTS Diététique",
    "BTS Économie Sociale Familiale",
    "BTS Services et Prestations des Secteurs Sanitaire et Social",
    "BTS Opticien-Lunetier",
    "BTS Communication",
    "BTS Design Graphique",
    "BTS Métiers de l'Audiovisuel",
    "BTS Photographie",
    "BTS Tourisme",
    "BTS Management en Hôtellerie-Restauration",
    "Doctorat en Informatique",
    "Doctorat en Mathématiques",
    "Doctorat en Physique",
    "Doctorat en Chimie",
    "Doctorat en Sciences de l'Ingénieur",
    "Doctorat en Sciences de l'Environnement",
    "Doctorat en Médecine",
    "Doctorat en Pharmacie",
    "Doctorat en Sciences Biomédicales",
    "Doctorat en Neurosciences",
    "Doctorat en Santé Publique",
    "Doctorat en Psychologie",
    "Doctorat en Sociologie",
    "Doctorat en Histoire",
    "Doctorat en Géographie",
    "Doctorat en Sciences Économiques",
    "Doctorat en Sciences de Gestion",
    "Doctorat en Sciences Politiques",
    "Doctorat en Droit",
    "Doctorat en Philosophie",
    "Doctorat en Lettres",
    "Doctorat en Linguistique",
    "Doctorat en Arts",
    "Doctorat en Études Cinématographiques",
    "Doctorat en Musicologie",
    "Doctorat en Architecture"
]
entreprises = [
    "TechCorp",
    "FinancePlus",
    "BioLab",
    "DataSoft",
    "InnoSolutions",
    "Microsoft",
    "Apple",
    "Google/Alphabet",
    "Amazon",
    "IBM",
    "Oracle",
    "SAP",
    "Salesforce",
    "Adobe",
    "Cisco",
    "Orange",
    "SFR",
    "Bouygues Telecom",
    "Vodafone",
    "Deutsche Telekom",
    "AT&T",
    "Verizon",
    "Nokia",
    "Ericsson",
    "Huawei",
    "Renault",
    "Stellantis/PSA",
    "Volkswagen",
    "Toyota",
    "BMW",
    "Mercedes-Benz",
    "Tesla",
    "Ford",
    "General Motors",
    "Michelin",
    "TotalEnergies",
    "EDF",
    "Engie",
    "Shell",
    "BP",
    "Exxon Mobil",
    "Chevron",
    "Iberdrola",
    "E.ON",
    "NextEra Energy",
    "BNP Paribas",
    "Crédit Agricole",
    "Société Générale",
    "BPCE",
    "HSBC",
    "Santander",
    "Deutsche Bank",
    "JPMorgan Chase",
    "Goldman Sachs",
    "AXA",
    "Carrefour",
    "Auchan",
    "Leclerc",
    "Lidl",
    "Aldi",
    "Tesco",
    "Walmart",
    "Costco",
    "Metro",
    "Ikea",
    "LVMH",
    "Kering",
    "Hermès",
    "L'Oréal",
    "Chanel",
    "Richemont",
    "Rolex",
    "Swatch Group",
    "Prada",
    "Estée Lauder",
    "Airbus",
    "Dassault Aviation",
    "Thales",
    "Safran",
    "Boeing",
    "Lockheed Martin",
    "Northrop Grumman",
    "BAE Systems",
    "Raytheon Technologies",
    "Leonardo",
    "Sanofi",
    "Novartis",
    "Roche",
    "Pfizer",
    "Johnson & Johnson",
    "Merck",
    "GlaxoSmithKline",
    "Bayer",
    "AstraZeneca",
    "Novo Nordisk",
    "Danone",
    "Nestlé",
    "Lactalis",
    "Pernod Ricard",
    "Coca-Cola",
    "PepsiCo",
    "Unilever",
    "Mondelez",
    "Mars",
    "Ferrero",
    "Samsung",
    "Intel",
    "NVIDIA",
    "Qualcomm",
    "Tencent",
    "Meta/Facebook",
    "Twitter",
    "Xiaomi",
    "Alibaba",
    "Accenture",
    "Free/Iliad",
    "KPN",
    "Telefónica",
    "América Móvil",
    "China Mobile",
    "NTT",
    "BT Group",
    "Swisscom",
    "Liberty Global",
    "Altice",
    "Hyundai",
    "Kia",
    "Honda",
    "Nissan",
    "Volvo",
    "Audi",
    "Porsche",
    "Ferrari",
    "Jaguar Land Rover",
    "Continental",
    "Saudi Aramco",
    "Gazprom",
    "Petrobras",
    "Eni",
    "Equinor",
    "Repsol",
    "ConocoPhillips",
    "Enel",
    "RWE",
    "Électricité de France",
    "Barclays",
    "UBS",
    "Credit Suisse",
    "ING",
    "Lloyds Banking Group",
    "Royal Bank of Canada",
    "Bank of America",
    "Morgan Stanley",
    "Citigroup",
    "Allianz",
    "Casino",
    "Système U",
    "Monoprix",
    "Rewe",
    "Edeka",
    "Kroger",
    "Target",
    "Sainsbury's",
    "Marks & Spencer",
    "Zara/Inditex",
    "Burberry",
    "Ralph Lauren",
    "Hugo Boss",
    "Gucci",
    "Dior",
    "Balenciaga",
    "Bulgari",
    "Valentino",
    "Armani",
    "Yves Saint Laurent",
    "Embraer",
    "Bombardier",
    "Rolls-Royce",
    "General Dynamics",
    "Textron",
    "UTC Aerospace",
    "Spirit AeroSystems",
    "MTU Aero Engines",
    "Honeywell",
    "GE Aviation",
    "Biogen",
    "Eli Lilly",
    "Bristol Myers Squibb",
    "Amgen",
    "Abbott",
    "Gilead Sciences",
    "Moderna",
    "Regeneron",
    "CSL",
    "Daiichi Sankyo",
    "Kraft Heinz",
    "Kellogg's",
    "General Mills",
    "Groupe Bel",
    "Barilla",
    "Tyson Foods",
    "Cargill",
    "Carlsberg",
    "Heineken",
    "JBS"
]
postes = [
    "Développeur Python",
    "Analyste Financier",
    "Chercheur",
    "Consultant IT",
    "Architecte Logiciel",
    "Développeur Full-Stack",
    "Assistant Manager",
    "Chargé de Gestion Administrative",
    "Comptable",
    "Assistant Contrôleur de Gestion",
    "Chercheur en Biologie",
    "Directeur de Recherche",
    "Data Scientist",
    "Machine Learning Engineer",
    "Pentester",
    "Responsable Sécurité des Systèmes d'Information",
    "Data Engineer",
    "Analyste de Données",
    "Ingénieur Électricien",
    "Chef de Projet Électrique",
    "Ingénieur Structures",
    "Conducteur de Travaux",
    "Ingénieur Mécanique",
    "Concepteur Mécanique",
    "Ingénieur en Robotique",
    "Développeur de Systèmes Embarqués",
    "Ingénieur Réseaux",
    "Architecte Télécom",
    "Ingénieur R&D Biotechnologies",
    "Chef de Projet Biotechnologies",
    "Ingénieur Chimiste",
    "Responsable Laboratoire",
    "Physicien Chercheur",
    "Ingénieur Physique",
    "Modélisateur Mathématique",
    "Quant (Analyste Quantitatif)",
    "Ingénieur Environnement",
    "Consultant en Développement Durable",
    "Épidémiologiste",
    "Chargé de Programme de Santé",
    "Chercheur en Neurosciences",
    "Ingénieur en Neurotechnologies",
    "Biologiste Médical",
    "Responsable de Laboratoire d'Analyses",
    "Psychologue Clinicien",
    "Psychothérapeute",
    "Cadre de Santé",
    "Infirmier Spécialisé",
    "Nutritionniste",
    "Consultant en Nutrition",
    "Psychologue",
    "Conseiller en Orientation",
    "Sociologue",
    "Chargé d'Études Sociales",
    "Historien",
    "Conservateur du Patrimoine",
    "Géographe",
    "Chargé d'Études Territoriales",
    "Analyste Politique",
    "Chargé d'Affaires Publiques",
    "Diplomate",
    "Analyste en Relations Internationales",
    "Économiste",
    "Analyste Économique",
    "Gestionnaire de Portefeuille",
    "Chef de Produit",
    "Responsable Marketing Digital",
    "Chef de Projet",
    "Responsable d'Unité Opérationnelle",
    "Responsable RH",
    "Chargé de Recrutement",
    "Juriste d'Entreprise",
    "Avocat",
    "Criminologue",
    "Analyste Criminal",
    "Éditeur",
    "Rédacteur",
    "Chargé de Relations Internationales",
    "Responsable Import-Export",
    "Traducteur",
    "Interprète",
    "Directeur Artistique",
    "Artiste Plasticien",
    "Réalisateur",
    "Producteur",
    "Musicologue",
    "Professeur de Musique",
    "Architecte",
    "Chef de Projet Architectural",
    "Designer Produit",
    "Directeur de Création",
    "Développeur Junior",
    "Technicien Informatique",
    "Analyste Statisticien",
    "Chargé d'Études Statistiques",
    "Assistant Ingénieur Physique",
    "Technicien de Laboratoire",
    "Assistant Ingénieur Chimiste",
    "Technicien Biologiste",
    "Assistant de Recherche",
    "Assistant Ingénieur",
    "Technicien Bureau d'Études",
    "Technicien Géologue",
    "Chargé d'Études Environnementales",
    "Assistant de Recherche Biologique",
    "Technicien de Laboratoire Biologique",
    "Assistant de Recherche Clinique",
    "Technicien de Laboratoire Médical",
    "Assistant Psychologue",
    "Conseiller en Insertion",
    "Infirmier",
    "Coordonnateur de Soins",
    "Assistant Juridique",
    "Clerc de Notaire",
    "Assistant Économiste",
    "Chargé d'Études Économiques",
    "Chargé d'Études Sociologiques",
    "Conseiller en Insertion Sociale",
    "Assistant de Conservation",
    "Médiateur Culturel",
    "Technicien SIG",
    "Collaborateur Parlementaire",
    "Chargé de Mission Politique",
    "Assistant Éditorial",
    "Conseiller Pédagogique",
    "Chargé de Mission Éducative",
    "Assistant Traducteur",
    "Formateur en Langues",
    "Assistant de Production",
    "Assistant Artistique",
    "Assistant Musical",
    "Chargé de Communication",
    "Community Manager",
    "Technicien Réseaux",
    "Technicien Support Informatique",
    "Technicien de Maintenance",
    "Responsable Maintenance",
    "Technicien Électricien",
    "Chargé d'Affaires en Électricité",
    "Conducteur de Travaux Junior",
    "Technicien Automaticien",
    "Chef de Chantier",
    "Technicien Bureau d'Études TP",
    "Responsable de Rayon",
    "Assistant Manager Commercial",
    "Commercial",
    "Chargé de Clientèle",
    "Assistant de Gestion",
    "Assistant Comptable",
    "Assistant de Direction",
    "Office Manager",
    "Assistant Import-Export",
    "Chargé de Mission International",
    "Conseiller Clientèle Bancaire",
    "Chargé d'Accueil Bancaire",
    "Technicien Agricole",
    "Conseiller Technique Agricole",
    "Technicien Paysagiste",
    "Conducteur de Travaux Paysagers",
    "Technicien Environnement",
    "Animateur Nature",
    "Diététicien",
    "Conseiller en Économie Sociale",
    "Chargé de Projet Social",
    "Gestionnaire Conseil",
    "Coordonnateur de Services",
    "Opticien",
    "Responsable de Magasin d'Optique",
    "Assistant Communication",
    "Chargé de Projet Communication",
    "Graphiste",
    "Webdesigner",
    "Technicien Audiovisuel",
    "Photographe",
    "Assistant Photographe",
    "Conseiller en Voyages",
    "Agent d'Accueil Touristique",
    "Assistant Manager Hôtelier",
    "Chef de Rang",
    "Enseignant-Chercheur en Informatique",
    "Directeur R&D Informatique",
    "Enseignant-Chercheur en Mathématiques",
    "Cryptologue",
    "Enseignant-Chercheur en Physique",
    "Ingénieur de Recherche",
    "Enseignant-Chercheur en Chimie",
    "Directeur R&D Chimie",
    "Enseignant-Chercheur",
    "Directeur Innovation",
    "Chercheur en Environnement",
    "Consultant Expert Environnemental",
    "Médecin",
    "Chercheur Clinicien",
    "Pharmacien",
    "Directeur R&D Pharmaceutique",
    "Chercheur Biomédical",
    "Directeur de Laboratoire",
    "Chercheur en Neurosciences",
    "Directeur de Recherche Neurologique",
    "Chercheur en Santé Publique",
    "Expert en Politiques de Santé",
    "Psychologue Chercheur",
    "Directeur de Recherche en Psychologie",
    "Sociologue Chercheur",
    "Expert en Analyse Sociétale",
    "Historien Chercheur",
    "Conservateur en Chef",
    "Géographe Chercheur",
    "Expert en Aménagement du Territoire",
    "Économiste Chercheur",
    "Consultant Expert en Économie",
    "Enseignant-Chercheur en Gestion",
    "Consultant Stratégique",
    "Politologue",
    "Conseiller Politique",
    "Professeur de Droit",
    "Juriste Expert",
    "Philosophe",
    "Éthicien",
    "Professeur de Littérature",
    "Critique Littéraire",
    "Linguiste",
    "Expert en Communication Interculturelle",
    "Chercheur en Arts",
    "Conservateur de Musée",
    "Chercheur en Cinéma",
    "Critique Cinématographique",
    "Musicologue",
    "Directeur Musical",
    "Architecte Chercheur",
    "Expert en Patrimoine Architectural"
]
competences = [

 # Développeur Python
  "Python",
  "Django",
  "Flask",
  "NumPy",
  "Pandas",
  "SQLAlchemy",
  "Git",
  "API REST",
  "Pytest",
  "Docker",

 # Analyste Financier
  "Excel",
  "Power BI",
  "Modélisation financière",
  "Analyse de risques",
  "Bloomberg Terminal",
  "VBA",
  "SQL",
  "Comptabilité",
  "Valorisation d'entreprise",
  "Analyse fondamentale",

 # Chercheur
  "Méthodologie de recherche",
  "Analyse statistique",
  "Publication scientifique",
  "R",
  "SPSS",
  "Revue de littérature",
  "Conception expérimentale",
  "Rédaction de subventions",
  "Propriété intellectuelle",
  "Éthique de recherche",

 # Consultant IT
  "Analyse des besoins",
  "Gestion de projets",
  "Transformation digitale",
  "Solutions Cloud",
  "Sécurité informatique",
  "Business Intelligence",
  "ERP/CRM",
  "Méthodologie Agile",
  "Audit informatique",
  "Gestion du changement",

 # Architecte Logiciel
  "Conception de systèmes",
  "Design patterns",
  "UML",
  "Microservices",
  "DevOps",
  "API Design",
  "Architecture Cloud",
  "Modélisation de données",
  "Sécurité applicative",
  "Documentation technique",

 # Développeur Full-Stack
  "JavaScript",
  "HTML/CSS",
  "React",
  "Node.js",
  "MongoDB",
  "RESTful API",
  "TypeScript",
  "Redux",
  "GraphQL",
  "Responsive Design",

 # Assistant Manager
  "Gestion administrative",
  "Coordination d'équipe",
  "Planification",
  "Suite Office",
  "Gestion d'agenda",
  "Communication interne",
  "Préparation de réunions",
  "Reporting",
  "Gestion des priorités",
  "Organisation d'événements",

 # Chargé de Gestion Administrative
  "Gestion documentaire",
  "Procédures administratives",
  "Saisie de données",
  "Archivage",
  "Logiciels de gestion",
  "Rédaction administrative",
  "Facturation",
  "Classement",
  "SAP",
  "Relation fournisseurs",

 # Comptable
  "Normes comptables",
  "Fiscalité",
  "Logiciels comptables",
  "Bilan",
  "Compte de résultat",
  "TVA",
  "Paie",
  "Réconciliation bancaire",
  "Clôture comptable",
  "Liasse fiscale",

 # Assistant Contrôleur de Gestion
  "Contrôle budgétaire",
  "Tableaux de bord",
  "Excel avancé",
  "SAP BFC",
  "Calcul de coûts",
  "Analyse d'écarts",
  "Prévisions financières",
  "Reporting mensuel",
  "KPI",
  "Consolidation",

 # Chercheur en Biologie
  "PCR",
  "Séquençage ADN",
  "Culture cellulaire",
  "Western Blot",
  "Microscopie confocale",
  "CRISPR",
  "Bioinformatique",
  "Clonage",
  "Cytométrie en flux",
  "Manipulation animale",

 # Directeur de Recherche
  "Management d'équipe scientifique",
  "Stratégie de recherche",
  "Financement de la recherche",
  "Publications internationales",
  "Partenariats scientifiques",
  "Gestion de budget R&D",
  "Propriété intellectuelle",
  "Transfert technologique",
  "Comités scientifiques",
  "Évaluation de la recherche",

 # Data Scientist
  "Machine Learning",
  "Deep Learning",
  "TensorFlow",
  "Scikit-learn",
  "Statistiques avancées",
  "Visualisation de données",
  "Jupyter Notebook",
  "Big Data",
  "Azure ML",
  "Feature engineering",

 # Machine Learning Engineer
  "MLOps",
  "Cloud computing",
  "Kubernetes",
  "CI/CD pour ML",
  "Optimisation de modèles",
  "Computer Vision",
  "NLP",
  "Traitement distribué",
  "AWS SageMaker",
  "Monitoring de modèles",

 # Pentester
  "Tests d'intrusion",
  "Analyse de vulnérabilités",
  "Kali Linux",
  "OWASP",
  "Forensics",
  "Scripting",
  "Social Engineering",
  "Reverse Engineering",
  "Sécurité réseau",
  "Cryptographie",

 # Responsable Sécurité des Systèmes d'Information
  "Gouvernance de sécurité",
  "Gestion des risques",
  "ISO 27001",
  "Réponse aux incidents",
  "Politique de sécurité",
  "Audits de sécurité",
  "RGPD",
  "Plan de continuité",
  "Sensibilisation à la sécurité",
  "Architecture de sécurité",

 # Data Engineer
  "ETL",
  "Data pipelines",
  "Hadoop",
  "Spark",
  "Data warehousing",
  "Airflow",
  "Kafka",
  "NoSQL",
  "Data modeling",
  "SQL avancé",

 # Analyste de Données
  "Analyse exploratoire",
  "Reporting automatisé",
  "Tableau Software",
  "Looker",
  "Data storytelling",
  "A/B Testing",
  "Segmentation client",
  "Analyses prédictives",
  "Google Analytics",
  "Data cleaning",

 # Ingénieur Électricien
  "Conception électrique",
  "AutoCAD Electrical",
  "Normes électriques",
  "Installations HT/BT",
  "Protection électrique",
  "Schémas unifilaires",
  "EPLAN",
  "Simulation électrique",
  "Efficacité énergétique",
  "Smart Grid",

 # Chef de Projet Électrique
  "Gestion de projet électrique",
  "Planification GANTT",
  "Coordination technique",
  "Appels d'offres",
  "Suivi de chantier",
  "Relation client",
  "Réglementation électrique",
  "Budgétisation",
  "Management d'équipe",
  "Revit MEP",

 # Ingénieur Structures
  "Calcul de structures",
  "Robot Structural",
  "Eurocode",
  "Analyse par éléments finis",
  "AutoCAD Structure",
  "BIM",
  "Conception parasismique",
  "Revit Structure",
  "Tekla Structures",
  "Dimensionnement béton armé",

 # Conducteur de Travaux
  "Pilotage de chantier",
  "Gestion de sous-traitants",
  "Lecture de plans",
  "Planning de travaux",
  "Contrôle qualité",
  "Sécurité chantier",
  "Microsoft Project",
  "Métrés",
  "Gestion de conflits",
  "Réunions de chantier",

 # Ingénieur Mécanique
  "CAO 3D",
  "SOLIDWORKS",
  "Simulation mécanique",
  "Résistance des matériaux",
  "ANSYS",
  "Mécanique des fluides",
  "Prototypage rapide",
  "Analyse thermique",
  "GD&T",
  "Fabrication additive",

 # Concepteur Mécanique
  "Conception de pièces",
  "Assemblage mécanique",
  "Catia",
  "Tôlerie",
  "Cotation fonctionnelle",
  "Dessin technique",
  "Usinage",
  "Moulage",
  "Calcul mécanique",
  "Pro/ENGINEER",

 # Ingénieur en Robotique
  "Programmation robotique",
  "ROS",
  "Vision par ordinateur",
  "Capteurs",
  "Cinématique",
  "Contrôle de mouvement",
  "Systèmes embarqués",
  "Automatisation",
  "SLAM",
  "Intelligence artificielle robotique",

 # Développeur de Systèmes Embarqués
  "C embarqué",
  "Microcontrôleurs",
  "RTOS",
  "Communication série",
  "Debug de systèmes embarqués",
  "Électronique numérique",
  "Drivers",
  "Firmware",
  "IoT",
  "ARM",

 # Ingénieur Réseaux
  "CCNA/CCNP",
  "Routage et switching",
  "VPN",
  "Firewalls",
  "TCP/IP",
  "SD-WAN",
  "Cisco",
  "Surveillance réseau",
  "Sécurité réseau",
  "Réseaux sans fil",

 # Architecte Télécom
  "Architecture télécom",
  "LTE/5G",
  "VoIP",
  "Transmission optique",
  "Réseaux d'opérateurs",
  "Dimensionnement",
  "IMS",
  "NFV/SDN",
  "Interconnexion",
  "QoS",

 # Ingénieur R&D Biotechnologies
  "Génie génétique",
  "Fermentation",
  "Purification de protéines",
  "Bioréacteurs",
  "Biocapteurs",
  "Biotechnologie industrielle",
  "Thérapie génique",
  "Scale-up",
  "Biologics",
  "Anticorps monoclonaux",

 # Chef de Projet Biotechnologies
  "Développement de procédés",
  "Réglementation biotech",
  "GMP",
  "Essais cliniques",
  "Transfert technologique",
  "Gestion de projet R&D",
  "Affaires réglementaires",
  "Budgétisation R&D",
  "Validation de méthodes",
  "Partenariats scientifiques",

 # Ingénieur Chimiste
  "Synthèse organique",
  "Chromatographie",
  "Spectrométrie de masse",
  "Formulation",
  "Chimie analytique",
  "Chimie industrielle",
  "Cinétique chimique",
  "Catalyse",
  "RMN",
  "Contrôle qualité",

 # Responsable Laboratoire
  "Management d'équipe technique",
  "Assurance qualité",
  "Normes ISO 17025",
  "Instrumentation analytique",
  "Validation de méthodes",
  "Gestion de stock",
  "Audits qualité",
  "Planification d'analyses",
  "Sécurité laboratoire",
  "Reporting analytique",

 # Physicien Chercheur
  "Physique quantique",
  "Modélisation physique",
  "Instrumentation",
  "Analyse de données expérimentales",
  "Simulations numériques",
  "Physique des matériaux",
  "Physique théorique",
  "Optique",
  "Méthodes spectroscopiques",
  "Cryogénie",

 # Ingénieur Physique
  "Physique appliquée",
  "Conception d'instruments",
  "Métrologie",
  "Optoélectronique",
  "Transfert thermique",
  "Matériaux avancés",
  "Énergies renouvelables",
  "Nanotechnologies",
  "Calcul numérique",
  "Tests physiques",

 # Modélisateur Mathématique
  "Modélisation stochastique",
  "Équations aux dérivées partielles",
  "Optimisation",
  "Mathématiques appliquées",
  "Analyse numérique",
  "MATLAB",
  "Méthodes Monte Carlo",
  "Séries temporelles",
  "Modèles prédictifs",
  "Statistiques bayésiennes",

 # Quant (Analyste Quantitatif)
  "Pricing d'options",
  "Modèles de risque",
  "Modèles de volatilité",
  "Calcul stochastique",
  "C++",
  "Trading algorithmique",
  "Time series forecasting",
  "Modélisation de marchés",
  "Backtesting",
  "Finance mathématique",

 # Ingénieur Environnement
  "Études d'impact",
  "ICPE",
  "Analyse de cycle de vie",
  "Gestion des déchets",
  "Dépollution",
  "ISO 14001",
  "Évaluation environnementale",
  "Développement durable",
  "Risques naturels",
  "Énergie renouvelable",

 # Consultant en Développement Durable
  "RSE",
  "Bilan carbone",
  "Économie circulaire",
  "ESG",
  "Agenda 2030",
  "Green IT",
  "Reporting extra-financier",
  "Certification environnementale",
  "Biodiversité",
  "Stratégie bas carbone",

 # Épidémiologiste
  "Biostatistiques",
  "Analyse de survie",
  "Études cohortes",
  "Modélisation épidémiologique",
  "Surveillance épidémiologique",
  "Logiciels SAS/STATA",
  "Santé publique",
  "Essais cliniques",
  "Analyse spatiale",
  "Facteurs de risque",

 # Chargé de Programme de Santé
  "Gestion de projets santé",
  "Santé publique",
  "Déterminants de santé",
  "Promotion de la santé",
  "Évaluation de programmes",
  "Partenariats santé",
  "Financements publics",
  "Analyse de besoins",
  "Santé communautaire",
  "Indicateurs sanitaires",

 # Chercheur en Neurosciences
  "Neuroimagerie",
  "EEG",
  "Électrophysiologie",
  "IRM fonctionnelle",
  "Neuropharmacologie",
  "Modèles animaux",
  "Analyse comportementale",
  "Neurosciences cognitives",
  "Optogénétique",
  "Neuroanatomie",

 # Ingénieur en Neurotechnologies
  "Brain-computer interface",
  "Traitement de signal neuronal",
  "Neuroprosthétique",
  "Dispositifs médicaux neurologiques",
  "Neurostimulation",
  "Algorithmes temps réel",
  "Neuromodulation",
  "Capteurs neurologiques",
  "Neurorobotics",
  "Biomécanique",

 # Biologiste Médical
  "Hématologie",
  "Biochimie clinique",
  "Microbiologie médicale",
  "Immunologie",
  "Parasitologie",
  "Virologie",
  "Biologie moléculaire",
  "Assurance qualité laboratoire",
  "Validation biologique",
  "Cytogénétique",

 # Responsable de Laboratoire d'Analyses
  "COFRAC",
  "Gestion d'équipe laboratoire",
  "Systèmes qualité",
  "LIS (Laboratory Information System)",
  "Accréditation laboratoire",
  "Contrôle qualité analytique",
  "Gestion des non-conformités",
  "Veille normative",
  "Réglementation laboratoire",
  "Relations cliniciens",

 # Psychologue Clinicien
  "Psychothérapie",
  "Évaluation psychologique",
  "Tests psychométriques",
  "Psychopathologie",
  "Entretien clinique",
  "TCC",
  "Analyse systémique",
  "Psychanalyse",
  "Relation d'aide",
  "Suivi thérapeutique",

 # Psychothérapeute
  "Thérapies brèves",
  "EMDR",
  "Hypnose thérapeutique",
  "Thérapie familiale",
  "Approche centrée sur la personne",
  "Gestalt-thérapie",
  "Mindfulness",
  "Alliance thérapeutique",
  "Psychosomatique",
  "Intervention de crise",

 # Cadre de Santé
  "Management d'équipe soignante",
  "Gestion des plannings",
  "Démarche qualité",
  "Coordination des soins",
  "Gestion de lits",
  "PMSI",
  "DPC",
  "Projets de service",
  "Relations patients",
  "Gestion des risques",

 # Infirmier Spécialisé
  "Soins spécialisés",
  "IADE/IBODE/Puéricultrice",
  "Protocoles de soins",
  "Prévention",
  "Éducation thérapeutique",
  "Logiciels de soins",
  "Transmissions ciblées",
  "Gestion douleur",
  "Urgences",
  "Bloc opératoire",

 # Nutritionniste
  "Bilan nutritionnel",
  "Rééquilibrage alimentaire",
  "Pathologies nutritionnelles",
  "Alimentation thérapeutique",
  "Composition corporelle",
  "Troubles du comportement alimentaire",
  "Éducation alimentaire",
  "Micronutrition",
  "Nutrition sportive",
  "Diététique",

 # Consultant en Nutrition
  "Formulation alimentaire",
  "Réglementation alimentaire",
  "Étiquetage nutritionnel",
  "Nutri-Score",
  "Allégations nutritionnelles",
  "Tendances alimentaires",
  "Profils nutritionnels",
  "Analyse sensorielle",
  "Nouveaux ingrédients",
  "Innovation alimentaire",

 # Psychologue
  "Accompagnement psychologique",
  "Bilan psychologique",
  "Animation de groupes",
  "Psychologie du développement",
  "Soutien psychologique",
  "Prévention",
  "Médiation",
  "Supervision",
  "Psychologie positive",
  "Évaluation cognitivo-comportementale",

 # Conseiller en Orientation
  "Bilan de compétences",
  "Tests d'orientation",
  "Connaissance métiers",
  "Coaching professionnel",
  "Accompagnement projet",
  "Techniques de recherche d'emploi",
  "Connaissance des formations",
  "VAE",
  "Entretien d'orientation",
  "Psychologie du travail",

 # Sociologue
  "Enquêtes sociologiques",
  "Études qualitatives",
  "Analyse de discours",
  "Théories sociologiques",
  "Ethnographie",
  "Entretiens semi-directifs",
  "Focus groups",
  "Sociologie des organisations",
  "Analyse de réseaux",
  "Changement social",

 # Chargé d'Études Sociales
  "Études d'impact social",
  "Analyse démographique",
  "Indicateurs sociaux",
  "Cartographie sociale",
  "Diagnostic territorial",
  "Politiques sociales",
  "Évaluation de dispositifs",
  "Analyse statistique sociale",
  "Études socio-économiques",
  "Veille sociale",

 # Historien
  "Recherche historique",
  "Analyse de sources primaires",
  "Archivistique",
  "Historiographie",
  "Paléographie",
  "Histoire comparative",
  "Histoire culturelle",
  "Méthodes quantitatives en histoire",
  "Humanités numériques",
  "Publication académique",

 # Conservateur du Patrimoine
  "Conservation préventive",
  "Gestion de collections",
  "Muséographie",
  "Exposition",
  "Inventaire",
  "Restauration",
  "Médiation culturelle",
  "Régie des œuvres",
  "Acquisition",
  "Patrimoine culturel",

 # Géographe
  "SIG",
  "Cartographie",
  "Analyse spatiale",
  "Télédétection",
  "Géomorphologie",
  "Géographie urbaine",
  "Aménagement du territoire",
  "Développement local",
  "Géographie économique",
  "Environnement",

 # Chargé d'Études Territoriales
  "Urbanisme",
  "Planification territoriale",
  "Diagnostic territorial",
  "Schémas directeurs",
  "Concertation publique",
  "Développement économique local",
  "Études d'impact",
  "Mobilité",
  "QGIS",
  "Observatoire territorial",

 # Analyste Politique
  "Analyse politique",
  "Relations internationales",
  "Géopolitique",
  "Veille politique",
  "Analyse électorale",
  "Politiques publiques",
  "Rédaction de notes",
  "Analyse discours politique",
  "Sciences politiques",
  "Institutions",

 # Chargé d'Affaires Publiques
  "Lobbying",
  "Relations institutionnelles",
  "Veille parlementaire",
  "Plaidoyer",
  "Négociation",
  "Stratégie d'influence",
  "Communication politique",
  "Réseautage",
  "Rédaction position papers",
  "Suivi législatif",

 # Diplomate
  "Négociation internationale",
  "Diplomatie multilatérale",
  "Relations bilatérales",
  "Droit international",
  "Protocole diplomatique",
  "Rédaction diplomatique",
  "Analyse géopolitique",
  "Médiation",
  "Représentation officielle",
  "Politique étrangère",

 # Analyste en Relations Internationales
  "Analyse conflits",
  "Coopération internationale",
  "Organisations internationales",
  "Sécurité internationale",
  "Développement international",
  "Géostratégie",
  "Veille internationale",
  "Rédaction rapports",
  "Analyse risque pays",
  "Doctrine stratégique",

 # Économiste
  "Modélisation économique",
  "Économétrie",
  "Analyse conjoncturelle",
  "Macroéconomie",
  "Microéconomie",
  "Prévisions économiques",
  "Stata/EViews",
  "Recherche économique",
  "Économie internationale",
  "Théorie économique",

 # Analyste Économique
  "Études sectorielles",
  "Intelligence économique",
  "Veille économique",
  "Benchmarking",
  "Indicateurs économiques",
  "Analyse de marché",
  "Économie appliquée",
  "Datamining",
  "Data visualization",
  "Études d'impact économique",

 # Gestionnaire de Portefeuille
  "Gestion d'actifs",
  "Analyse financière",
  "Allocation d'actifs",
  "Gestion de risque",
  "Produits dérivés",
  "Performance reporting",
  "Optimisation de portefeuille",
  "Front office",
  "Marchés financiers",
  "Stratégies d'investissement",

 # Chef de Produit
  "Marketing produit",
  "Études de marché",
  "Lancement de produit",
  "Pricing",
  "Positionnement",
  "Roadmap produit",
  "Customer insights",
  "Competitive analysis",
  "User Experience",
  "A/B testing",

 # Responsable Marketing Digital
  "SEO/SEA",
  "Analytics",
  "Social media",
  "Email marketing",
  "Content marketing",
  "CRM",
  "Conversion optimization",
  "Marketing automation",
  "Acquisition client",
  "Inbound marketing",

 # Chef de Projet
  "Gestion de planning",
  "Budgétisation",
  "Coordination d'équipe",
  "Analyse de risques",
  "Reporting",
  "Cahier des charges",
  "Méthodes agiles",
  "Suivi d'avancement",
  "Communication projet",
  "Prince2/PMP/Scrum",

 # Responsable d'Unité Opérationnelle
  "Management opérationnel",
  "Gestion P&L",
  "Indicateurs de performance",
  "Amélioration continue",
  "Gestion de production",
  "BPR",
  "Supply chain",
  "Lean management",
  "Gestion budgétaire",
  "Stratégie opérationnelle",

 # Responsable RH
  "Recrutement",
  "GPEC",
  "Relations sociales",
  "Formation",
  "Droit social",
  "Rémunération",
  "SIRH",
  "Développement RH",
  "Mobilité interne",
  "Conduite du changement",

 # Chargé de Recrutement
  "Sourcing",
  "Entretiens de recrutement",
  "Assessment",
  "ATS",
  "Rédaction d'annonces",
  "LinkedIn Recruiter",
  "Marque employeur",
  "Onboarding",
  "Réseaux sociaux professionnels",
  "Jobboards",

 # Juriste d'Entreprise
  "Droit des contrats",
  "Droit des sociétés",
  "Propriété intellectuelle",
  "Droit commercial",
  "Droit social",
  "Contentieux",
  "Conformité",
  "Droit de la concurrence",
  "RGPD",
  "Négociation juridique",

 # Avocat
  "Conseil juridique",
  "Contentieux",
  "Plaidoirie",
  "Rédaction juridique",
  "Veille juridique",
  "Négociation",
  "Droit civil/pénal/administratif",
  "Médiation",
  "Procédure",
  "Droit spécialisé",

 # Criminologue
  "Analyse criminelle",
  "Profiling",
  "Victimologie",
  "Sociologie criminelle",
  "Statistiques criminelles",
  "Prévention de la délinquance",
  "Systèmes judiciaires",
  "Réinsertion",
  "Criminalistique",
  "Politique pénale",

 # Analyste Criminal
  "Renseignement criminel",
  "Analyse de scène de crime",
  "Investigation numérique",
  "Geographic profiling",
  "Analyse de réseau criminel",
  "Base de données criminelles",
  "Analyse comportementale",
  "Analyse de tendances",
  "Analyse de téléphonie",
  "Forensic",

 # Éditeur
  "Édition littéraire",
  "Correction",
  "Évaluation manuscrits",
  "Production éditoriale",
  "Négociation droits",
  "Marketing éditorial",
  "Chaîne graphique",
  "Coordination éditoriale",
  "Édition numérique",
  "Stratégie éditoriale",

 # Rédacteur
  "Rédaction web",
  "Copywriting",
  "SEO content",
  "Storytelling",
  "Journalisme",
  "Relecture",
  "Réécriture",
  "Synthèse",
  "Content marketing",
  "Rédaction technique",

 # Chargé de Relations Internationales
  "Coopération internationale",
  "Projets internationaux",
  "Mobilité internationale",
  "Interculturalité",
  "Rédaction internationale",
  "Protocole",
  "Veille internationale",
  "Gestion d'événements internationaux",
  "Relations diplomatiques",
  "Partenariats internationaux",

 # Responsable Import-Export
  "Commerce international",
  "Incoterms",
  "Douane",
  "Logistique internationale",
  "Négociation internationale",
  "Réglementation export",
  "Forex",
  "Crédits documentaires",
  "Sourcing international",
  "Transport international",

 # Traducteur
  "Traduction spécialisée",
  "CAT tools",
  "Localisation",
  "Terminologie",
  "Relecture bilingue",
  "Post-édition",
  "Traduction assermentée",
  "Gestion de glossaires",
  "Adaptation culturelle",
  "SDL Trados/MemoQ",

 # Interprète
  "Interprétation simultanée",
  "Interprétation consécutive",
  "Interprétation de liaison",
  "Prise de notes",
  "Terminologie spécialisée",
  "Expression orale",
  "Gestion du stress",
  "Culture générale",
  "Interprétation de conférence",
  "Éthique professionnelle",

 # Directeur Artistique
  "Direction créative",
  "Conception visuelle",
  "Adobe Creative Suite",
  "Branding",
  "Direction photo/vidéo",
  "Typographie",
  "Design graphique",
  "Communication visuelle",
  "Direction d'équipe créative",
  "Identité de marque",

 # Artiste Plasticien
  "Techniques artistiques",
  "Dessin",
  "Peinture",
  "Sculpture",
  "Installation",
  "Art numérique",
  "Photographie artistique",
  "Performance",
  "Art conceptuel",
  "Expositions",

 # Réalisateur
  "Direction d'acteurs",
  "Mise en scène",
  "Scénarisation",
  "Production audiovisuelle",
  "Montage",
  "Direction photo",
  "Narration visuelle",
  "Storyboard",
  "Esthétique filmique",
  "Postproduction",

 # Producteur
  "Financement de projets",
  "Budgétisation production",
  "Casting",
  "Droits audiovisuels",
  "Logistique de tournage",
  "Distribution",
  "Marketing cinéma/TV",
  "Négociation contrats",
  "Production exécutive",
  "Coproduction",

 # Musicologue
  "Histoire de la musique",
  "Analyse musicale",
  "Recherche musicologique",
  "Paléographie musicale",
  "Ethnomusicologie",
  "Théorie musicale",
  "Édition critique",
  "Catalogue musical",
  "Organologie",
  "Archives sonores",

 # Professeur de Musique
  "Pédagogie musicale",
  "Solfège",
  "Direction d'ensemble",
  "Technique instrumentale",
  "Éveil musical",
  "Improvisation",
  "Accompagnement",
  "Arrangements",
  "Évaluation musicale",
  "Répertoire",

 # Architecte
  "Conception architecturale",
  "AutoCAD",
  "Revit Architecture",
  "Réglementation construction",
  "Dessin technique",
  "Maîtrise d'œuvre",
  "Développement durable",
  "Modélisation 3D",
  "Permis de construire",
  "Suivi de chantier",

 # Chef de Projet Architectural
  "Coordination d'études",
  "Programmation architecturale",
  "Relations clients",
  "BIM Management",
  "Appels d'offres",
  "Planification architecturale",
  "Suivi financier",
  "Gestion équipe pluridisciplinaire",
  "Concours d'architecture",
  "Développement urbain",

 # Designer Produit
  "Conception produit",
  "SketchUp",
  "Prototypage",
  "Design thinking",
  "UX Design",
  "Écoconception",
  "Ergonomie",
  "Rendus 3D",
  "Tendances design",
  "Design industriel",

 # Directeur de Création
  "Stratégie créative",
  "Direction artistique",
  "Management équipe créative",
  "Présentation client",
  "Innovation",
  "Storytelling",
  "Maîtrise des trends",
  "Benchmark créatif",
  "Conception campagnes",
  "Direction de shooting",

 # Développeur Junior
  "Développement web",
  "Programmation basique",
  "HTML/CSS",
  "Bases de données simples",
  "Tests unitaires",
  "Débogage",
  "Git basique",
  "Intégration web",
  "Documentation code",
  "Framework standard",

 # Technicien Informatique
  "Support utilisateur",
  "Maintenance informatique",
  "Installation matériel/logiciel",
  "Diagnostic de pannes",
  "Systèmes d'exploitation",
  "Réseaux locaux",
  "Active Directory",
  "Sauvegarde de données",
  "Help desk",
  "Sécurité informatique basique",

 # Analyste Statisticien
  "Analyse statistique",
  "SPSS/SAS/R",
  "Conception d'enquêtes",
  "Échantillonnage",
  "Tests statistiques",
  "Reporting",
  "Analyse multivariée",
  "Data mining",
  "Modélisation statistique",
  "Visualisation de données",

 # Chargé d'Études Statistiques
  "Traitement de données",
  "Collecte de données",
  "Tableaux croisés",
  "Analyse quantitative",
  "Études de marché",
  "Excel avancé",
  "Présentation de résultats",
  "Méthodologie d'enquête",
  "Sondages",
  "Analyse qualitative",

 # Assistant Ingénieur Physique
  "Mesures physiques",
  "Instrumentation scientifique",
  "Protocoles expérimentaux",
  "Calibration",
  "Collecte de données physiques",
  "Analyse préliminaire",
  "Maintenance d'équipements",
  "Sécurité laboratoire",
  "Assistance recherche",
  "Rédaction technique",

 # Technicien de Laboratoire
  "Techniques analytiques",
  "Préparation d'échantillons",
  "Analyses physicochimiques",
  "Contrôle qualité",
  "Maintenance équipements",
  "Procédures laboratoire",
  "Normes ISO",
  "Traçabilité",
  "HPLC",
  "Spectrophotométrie",

 # Assistant Ingénieur Chimiste
  "Synthèse chimique",
  "Analyses chimiques",
  "HPLC/GC/MS",
  "Préparations chimiques",
  "Protocoles chimiques",
  "Sécurité chimique",
  "Gestion stock produits",
  "Rédaction rapports techniques",
  "Assistance projets R&D",
  "Normes laboratoire",

 # Technicien Biologiste
  "Techniques biologiques",
  "Culture cellulaire",
  "PCR",
  "ELISA",
  "Microscopie",
  "Préparation échantillons biologiques",
  "Extraction ADN/ARN",
  "Stérilisation",
  "Milieux de culture",
  "Analyses biologiques",

 # Assistant de Recherche
  "Revue littérature",
  "Collecte de données",
  "Analyse préliminaire",
  "Assistance expérimentale",
  "Rédaction scientifique",
  "Organisation laboratoire",
  "Bibliographie",
  "Présentation résultats",
  "Méthodologie de recherche",
  "Documentation scientifique",

 # Assistant Ingénieur
  "Support technique",
  "Conception assistée",
  "Tests techniques",
  "Documentation technique",
  "Suivi de projets",
  "Préparation d'expériences",
  "Analyse de données techniques",
  "Assistance conception",
  "Maintenance équipements",
  "Rapport technique",

 # Technicien Bureau d'Études
  "Dessin technique",
  "CAO 2D/3D",
  "Lecture de plans",
  "Métrés",
  "Relevés terrain",
  "Mise en plan",
  "Détails techniques",
  "Nomenclature",
  "Dossiers techniques",
  "Schématisation",

 # Technicien Géologue
  "Cartographie géologique",
  "Échantillonnage terrain",
  "Analyses de sol",
  "SIG basique",
  "Géotechnique",
  "Logs stratigraphiques",
  "Préparation échantillons",
  "Analyses pétrographiques",
  "Rapport géologique",
  "Sondages",

 # Chargé d'Études Environnementales
  "Évaluation impact",
  "Prélèvements environnementaux",
  "Analyses environnementales",
  "Cartographie environnementale",
  "Législation environnementale",
  "Biodiversité",
  "Études faune/flore",
  "Reporting environnemental",
  "Diagnostic pollution",
  "Mesures environnementales",

 # Assistant de Recherche Biologique
  "Assistance expérimentale biologique",
  "Analyses biologiques",
  "Traitement données biologiques",
  "Préparation matériel biologique",
  "Protocoles biologiques",
  "Assistance projets biologiques",
  "Documentation biologique",
  "Maintenance laboratoire biologique",
  "Suivi expériences",
  "Rapport biologique",

 # Technicien de Laboratoire Biologique
  "Techniques biologiques",
  "Analyses microbiologiques",
  "Préparation échantillons",
  "Contrôle qualité biologique",
  "Stérilisation",
  "Milieux de culture",
  "Techniques moléculaires",
  "Cytologie",
  "Histologie",
  "Hématologie",

 # Assistant de Recherche Clinique
  "Essais cliniques",
  "Recrutement patients",
  "CRF",
  "BPC",
  "Suivi patients",
  "Pharmacovigilance",
  "Documentation clinique",
  "Consentement éclairé",
  "Monitoring",
  "Rapport clinique",

 # Technicien de Laboratoire Médical
  "Analyses médicales",
  "Prélèvements",
  "Hématologie",
  "Biochimie clinique",
  "Microbiologie médicale",
  "Immunologie",
  "Gestion échantillons",
  "Assurance qualité",
  "Automates laboratoire",
  "Traçabilité échantillons",

 # Assistant Psychologue
  "Tests psychologiques",
  "Entretien psychologique",
  "Soutien psychologique",
  "Animation groupe",
  "Questionnaires psychologiques",
  "Bilans psychologiques",
  "Accueil patients",
  "Observation clinique",
  "Documentation psychologique",
  "Accompagnement",

 # Conseiller en Insertion
  "Accompagnement social",
  "Entretien d'insertion",
  "Orientation professionnelle",
  "Techniques recherche emploi",
  "Connaissance dispositifs insertion",
  "Évaluation compétences",
  "Partenariats sociaux",
  "Ateliers collectifs",
  "Suivi parcours",
  "Connaissance publics fragilisés",

 # Infirmier
  "Soins infirmiers",
  "Administration traitements",
  "Évaluation clinique",
  "Dossier de soins",
  "Prévention",
  "Hygiène hospitalière",
  "Gestes d'urgence",
  "Éducation santé",
  "Relation d'aide",
  "Protocoles de soins",

 # Coordonnateur de Soins
  "Coordination parcours patient",
  "Planification soins",
  "Liaison équipes médicales",
  "Gestion des admissions",
  "Suivi post-hospitalisation",
  "Relations familles",
  "Gestion de cas complexes",
  "DMP",
  "Coordination pluridisciplinaire",
  "Évaluation besoins",

 # Assistant Juridique
  "Rédaction juridique",
  "Recherche juridique",
  "Secrétariat juridique",
  "Constitution dossiers",
  "Préparation procédures",
  "Veille juridique",
  "Classement",
  "Relation clients",
  "Gestion agenda juridique",
  "Rédaction courriers juridiques",

 # Clerc de Notaire
  "Formalités notariales",
  "Rédaction actes",
  "Vérification pièces",
  "Relation clients notariat",
  "Droit immobilier",
  "Succession",
  "Publicité foncière",
  "Formalités administratives",
  "Droit de la famille",
  "Logiciels notariaux",

 # Assistant Économiste
  "Collecte données économiques",
  "Analyse économique basique",
  "Traitement statistique",
  "Veille économique",
  "Rapports économiques",
  "Recherche documentaire",
  "Bases de données économiques",
  "Bibliographie économique",
  "Organisation colloques",
  "Notes économiques",

 # Chargé d'Études Économiques
  "Études sectorielles",
  "Analyse marché",
  "Indicateurs économiques",
  "Prévisions",
  "Benchmarking",
  "Rapports économiques",
  "Analyse concurrentielle",
  "Veille stratégique",
  "Intelligence économique",
  "Méthodologie d'enquête",

 # Chargé d'Études Sociologiques
  "Enquêtes sociologiques",
  "Entretiens qualitatifs",
  "Analyse sociologique",
  "Questionnaires",
  "Traitement données sociales",
  "Études territoriales",
  "Analyse démographique",
  "Diagnostics sociaux",
  "Rapports sociologiques",
  "Méthodologie enquête sociale",

 # Conseiller en Insertion Sociale
  "Accompagnement social",
  "Connaissance dispositifs sociaux",
  "Entretien social",
  "Évaluation sociale",
  "Partenariats sociaux",
  "Médiation sociale",
  "Connaissance publics précaires",
  "Droits sociaux",
  "Logement social",
  "Ateliers collectifs",

 # Assistant de Conservation
  "Inventaire collections",
  "Récolement",
  "Conservation préventive",
  "Documentation muséale",
  "Manipulation œuvres",
  "Conditionnement",
  "Expositions",
  "Base de données patrimoniales",
  "Accueil public",
  "Assistance régie",

 # Médiateur Culturel
  "Médiation culturelle",
  "Visites guidées",
  "Conception ateliers",
  "Animation culturelle",
  "Pédagogie culturelle",
  "Accueil des publics",
  "Conception supports",
  "Partenariats culturels",
  "Programmation culturelle",
  "Connaissance patrimoniale",

 # Technicien SIG
  "QGIS/ArcGIS",
  "Cartographie",
  "Bases de données géographiques",
  "Géoréférencement",
  "Analyse spatiale basique",
  "CAO basique",
  "Relevés terrain",
  "Traitements raster/vecteur",
  "Mise en page cartographique",
  "Données géographiques",

 # Collaborateur Parlementaire
  "Rédaction politique",
  "Veille législative",
  "Organisation agenda politique",
  "Relations institutionnelles",
  "Notes politiques",
  "Organisation événements politiques",
  "Relation presse politique",
  "Suivi questions parlementaires",
  "Gestion correspondance",
  "Connaissance institutions",

 # Chargé de Mission Politique
  "Expertise thématique",
  "Rédaction discours",
  "Relation élus",
  "Stratégie politique",
  "Dossiers politiques",
  "Veille territoriale",
  "Concertation",
  "Communication publique",
  "Partenariats politiques",
  "Argumentation",

 # Assistant Éditorial
  "Relecture",
  "Correction orthographique",
  "Suivi éditorial",
  "Préparation manuscrits",
  "Iconographie",
  "Relation auteurs",
  "Planning éditorial",
  "Secrétariat édition",
  "BAT",
  "Chaîne éditoriale",

 # Conseiller Pédagogique
  "Accompagnement enseignants",
  "Ingénierie pédagogique",
  "Animation formation",
  "Ressources pédagogiques",
  "Observation classe",
  "Analyse pratiques",
  "Connaissance programmes",
  "Outils numériques éducatifs",
  "Évaluation pédagogique",
  "Innovation pédagogique",

 # Chargé de Mission Éducative
  "Projets éducatifs",
  "Partenariats éducatifs",
  "Animation éducative",
  "Politiques éducatives",
  "Coordination dispositifs",
  "Médiation scolaire",
  "Réussite éducative",
  "Relation établissements",
  "Ingénierie éducative",
  "Évaluation dispositifs",

 # Assistant Traducteur
  "Traduction basique",
  "Relecture bilingue",
  "Gestion terminologie",
  "Recherche documentaire",
  "Outils TAO basiques",
  "Support traduction",
  "Préparation documents",
  "Mise en page",
  "Vérification linguistique",
  "Alignement de textes",

 # Formateur en Langues
  "Pédagogie linguistique",
  "Animation cours langues",
  "Évaluation linguistique",
  "Conception supports",
  "Formations sur mesure",
  "CECRL",
  "Ateliers linguistiques",
  "Communication interculturelle",
  "Approche communicative",
  "E-learning langues",

 # Assistant de Production
  "Logistique production",
  "Planning tournage",
  "Budget production",
  "Coordination équipes",
  "Repérages",
  "Autorisations tournage",
  "Casting",
  "Dépouillement scénario",
  "Organisation plateau",
  "Suivi post-production",

 # Assistant Artistique
  "Support création",
  "Recherche artistique",
  "Coordination projets artistiques",
  "Relation artistes",
  "Organisation expositions",
  "Documentation artistique",
  "Veille artistique",
  "Préparation matériel",
  "Assistance technique",
  "Communication artistique",

 # Assistant Musical
  "Partition",
  "Organisation répétitions",
  "Logistique concerts",
  "Relation musiciens",
  "Enregistrement",
  "Préparation matériel",
  "Régie musicale",
  "Archives musicales",
  "Support artistique",
  "Administration musicale",

 # Chargé de Communication
  "Stratégie communication",
  "Relation presse",
  "Rédaction contenus",
  "Community management",
  "Événementiel",
  "Outils communication",
  "Plan média",
  "Communication interne",
  "Communication corporate",
  "Évaluation actions",

 # Community Manager
  "Animation réseaux sociaux",
  "Création contenus",
  "Modération",
  "Social media strategy",
  "Analyse audiences",
  "Veille e-réputation",
  "Linkedin/Facebook/Instagram/Twitter",
  "Planification posts",
  "Engagement communautaire",
  "Analytics réseaux sociaux",

 # Technicien Réseaux
  "Installation réseaux",
  "Maintenance réseaux",
  "Configuration équipements",
  "Diagnostic pannes",
  "Câblage",
  "TCP/IP",
  "Sécurité réseaux basique",
  "Switching/Routing",
  "Documentation réseaux",
  "VLAN",

 # Technicien Support Informatique
  "Dépannage informatique",
  "Helpdesk",
  "Installation logiciels",
  "Configuration poste",
  "Résolution incidents",
  "Assistance utilisateurs",
  "Maintenance préventive",
  "Inventaire matériel",
  "Documentation procédures",
  "Télémaintenance",

 # Technicien de Maintenance
  "Maintenance préventive",
  "Maintenance curative",
  "Diagnostic pannes",
  "GMAO",
  "Lecture schémas techniques",
  "Électrotechnique",
  "Mécanique",
  "Hydraulique",
  "Pneumatique",
  "Sécurité maintenance",

 # Responsable Maintenance
  "Gestion équipe maintenance",
  "Planification maintenance",
  "Budget maintenance",
  "KPI maintenance",
  "TPM",
  "Amélioration continue",
  "Gestion sous-traitants",
  "Audits techniques",
  "Gestion stock pièces",
  "Fiabilisation",

 # Technicien Électricien
  "Installation électrique",
  "Dépannage électrique",
  "Schémas électriques",
  "Habilitation électrique",
  "NFC 15-100",
  "Câblage",
  "Tableaux électriques",
  "Mesures électriques",
  "Automatismes basiques",
  "Maintenance électrique",

 # Chargé d'Affaires en Électricité
  "Chiffrage électricité",
  "Relation clients",
  "Études électriques",
  "Coordination chantier",
  "Suivi financier",
  "Négociation",
  "Appels d'offres électriques",
  "Planification travaux",
  "Relation fournisseurs",
  "Réception travaux",

 # Conducteur de Travaux Junior
  "Suivi chantier",
  "Coordination équipes",
  "Lecture plans",
  "Planning travaux",
  "Contrôle qualité",
  "Sécurité chantier",
  "Relation sous-traitants",
  "Reporting",
  "Réunions chantier",
  "Gestion approvisionnements",

 # Technicien Automaticien
  "Automatismes industriels",
  "Programmation API",
  "Schémas électriques",
  "Supervision",
  "Mise en service",
  "Dépannage automatismes",
  "HMI",
  "Capteurs/actionneurs",
  "Documentation technique",
  "Maintenance automatismes",

 # Chef de Chantier
  "Encadrement équipe",
  "Organisation chantier",
  "Suivi plannings",
  "Contrôle travaux",
  "Sécurité travaux",
  "Approvisionnement",
  "Relations sous-traitants",
  "Implantation",
  "Lecture plans",
  "Réunions chantier",

 # Technicien Bureau d'Études TP
  "Plans TP",
  "Métrés TP",
  "Études de prix",
  "Autocad",
  "Relevés terrain",
  "VRD",
  "Cubatures",
  "Plans d'exécution",
  "Détails techniques",
  "Documentation technique TP",

 # Responsable de Rayon
  "Gestion équipe rayon",
  "Merchandising",
  "Gestion stocks",
  "Relation clients",
  "Animation commerciale",
  "Indicateurs commerciaux",
  "Gestion commandes",
  "Implantation produits",
  "Contrôle qualité",
  "Gestion promotions",

 # Assistant Manager Commercial
  "Support ventes",
  "Administration commerciale",
  "Suivi clients",
  "Reporting commercial",
  "CRM",
  "Organisation réunions",
  "Suivi objectifs",
  "Gestion agenda commercial",
  "Préparation offres",
  "Suivi commandes",

 # Commercial
  "Prospection",
  "Négociation",
  "Closing",
  "Développement portefeuille",
  "Fidélisation clients",
  "Techniques de vente",
  "Propositions commerciales",
  "B2B/B2C",
  "Objectifs commerciaux",
  "Reporting activité",

 # Chargé de Clientèle
  "Relation clients",
  "Conseil client",
  "Vente additionnelle",
  "Gestion réclamations",
  "Suivi satisfaction",
  "SAV",
  "Fidélisation",
  "Analyses besoins",
  "Gestion portefeuille",
  "Administration clients",

 # Assistant de Gestion
  "Gestion administrative",
  "Comptabilité basique",
  "Suivi fournisseurs",
  "Suivi clients",
  "Facturation",
  "Organisation",
  "Secrétariat",
  "Gestion agenda",
  "Reporting",
  "Classement",

 # Assistant Comptable
  "Saisie comptable",
  "Lettrage",
  "Rapprochement bancaire",
  "Préparation bilan",
  "Comptabilité fournisseurs",
  "Comptabilité clients",
  "Déclarations fiscales",
  "Gestion trésorerie",
  "Calcul TVA",
  "Relances clients",

 # Assistant de Direction
  "Support direction",
  "Gestion agenda direction",
  "Organisation réunions",
  "Rédaction compte-rendu",
  "Filtrage appels",
  "Préparation dossiers",
  "Organisation déplacements",
  "Correspondance",
  "Gestion priorités",
  "Confidentialité",

 # Office Manager
  "Gestion bureau",
  "Coordination administrative",
  "Achats fournitures",
  "Organisation événements",
  "Accueil",
  "Relation prestataires",
  "Gestion locaux",
  "Services généraux",
  "Procédures administratives",
  "Budget administratif",

 # Assistant Import-Export
  "Administration import-export",
  "Documents douaniers",
  "Logistique internationale",
  "Suivi commandes internationales",
  "Relation transitaires",
  "Incoterms",
  "Facturation internationale",
  "Documentation export",
  "Suivi expéditions",
  "Crédits documentaires",

 # Chargé de Mission International
  "Développement international",
  "Coordination projets internationaux",
  "Veille marchés étrangers",
  "Relations partenaires étrangers",
  "Mobilité internationale",
  "Organisation missions",
  "Négociations interculturelles",
  "Reporting international",
  "Montage projets internationaux",
  "Recherche financements",

 # Conseiller Clientèle Bancaire
  "Conseil bancaire",
  "Produits bancaires",
  "Épargne",
  "Crédit",
  "Assurance",
  "KYC",
  "Analyse risque client",
  "Conformité bancaire",
  "Relation client bancaire",
  "Vente produits financiers",

 # Chargé d'Accueil Bancaire
  "Accueil clients banque",
  "Opérations courantes",
  "DAB/GAB",
  "Services bancaires basiques",
  "Orientation clients",
  "Conformité bancaire basique",
  "Tenue de caisse",
  "Vente produits simples",
  "Administration agence",
  "Procédures bancaires",

 # Technicien Agricole
  "Techniques culturales",
  "Élevage",
  "Machinisme agricole",
  "Protection des cultures",
  "Irrigation",
  "Conseil agricole",
  "Suivi parcelles",
  "Expérimentation agricole",
  "Traçabilité agricole",
  "Diagnostic cultural",

 # Conseiller Technique Agricole
  "Conseil exploitation",
  "Diagnostic agricole",
  "Préconisations techniques",
  "Suivi technico-économique",
  "Réglementation agricole",
  "Formation agriculteurs",
  "Démonstrations techniques",
  "Veille technique agricole",
  "Animation groupes",
  "Développement durable agricole",

 # Technicien Paysagiste
  "Création espaces verts",
  "Plantation",
  "Maçonnerie paysagère",
  "Plans aménagement",
  "Entretien espaces verts",
  "Connaissance végétaux",
  "Arrosage automatique",
  "Lecture plans paysagers",
  "Phytosanitaire",
  "Devis paysagers",

 # Conducteur de Travaux Paysagers
  "Gestion chantiers paysagers",
  "Management équipe paysagiste",
  "Planification travaux paysagers",
  "Chiffrage paysager",
  "Coordination sous-traitants",
  "Suivi fournisseurs végétaux",
  "Contrôle qualité paysager",
  "Relation clients",
  "Réception travaux",
  "Gestion matériel paysager",

 # Technicien Environnement
  "Prélèvements environnementaux",
  "Analyses environnementales",
  "Suivi indicateurs",
  "Contrôle pollution",
  "Gestion déchets",
  "Réglementation environnementale",
  "Surveillance sites",
  "Mesures environnementales",
  "Rapports environnementaux",
  "Sensibilisation environnementale",

 # Animateur Nature
  "Éducation environnementale",
  "Animation nature",
  "Connaissance biodiversité",
  "Pédagogie environnementale",
  "Conception ateliers nature",
  "Sorties terrain",
  "Médiation environnementale",
  "Supports pédagogiques",
  "Connaissance écosystèmes",
  "Sensibilisation développement durable",

 # Diététicien
  "Bilan nutritionnel",
  "Plan alimentaire",
  "Éducation nutritionnelle",
  "Suivi patients",
  "Pathologies nutritionnelles",
  "HACCP",
  "Ateliers nutrition",
  "Équilibre alimentaire",
  "Composition des aliments",
  "Outils d'évaluation nutritionnelle",

 # Conseiller en Économie Sociale
  "Action sociale",
  "Budget familial",
  "Logement social",
  "Droits sociaux",
  "Suivi social",
  "Animation collective",
  "Médiation familiale",
  "Insertion sociale",
  "Prévention surendettement",
  "Connaissance dispositifs sociaux",

 # Chargé de Projet Social
  "Développement projets sociaux",
  "Coordination partenaires",
  "Diagnostic social",
  "Ingénierie sociale",
  "Évaluation dispositifs",
  "Demandes subventions",
  "Animation territoriale",
  "Développement communautaire",
  "Reporting social",
  "Politique de la ville",

 # Gestionnaire Conseil
  "Conseil assuré",
  "Gestion dossiers",
  "Liquidation prestations",
  "Législation sociale",
  "Relation usagers",
  "Calcul droits",
  "Traitement réclamations",
  "Suivi dossiers",
  "Contrôle conformité",
  "Information réglementaire",

 # Coordonnateur de Services
  "Coordination équipes",
  "Organisation services",
  "Planification interventions",
  "Suivi qualité",
  "Relations partenaires",
  "Évaluation besoins",
  "Interface usagers",
  "Reporting activité",
  "Optimisation ressources",
  "Procédures de service",

 # Opticien
  "Vente lunettes",
  "Montage lunettes",
  "Conseil optique",
  "Prise de mesures",
  "Examen de vue",
  "Gestion magasin optique",
  "Adaptation lentilles",
  "Législation optique",
  "Relations mutuelles",
  "Merchandising optique",

 # Responsable de Magasin d'Optique
  "Management équipe optique",
  "Gestion point de vente",
  "Relation clients",
  "Animation commerciale",
  "Gestion stocks",
  "Stratégie commerciale",
  "Recrutement optique",
  "Analyse performance",
  "Marketing optique",
  "Gestion administrative",

 # Assistant Communication
  "Support communication",
  "Relations presse",
  "Organisation événements",
  "Rédaction contenus",
  "Mise à jour site web",
  "Création supports",
  "Diffusion information",
  "Revue de presse",
  "Administration communication",
  "Relation prestataires",

 # Chargé de Projet Communication
  "Stratégie de communication",
  "Gestion campagnes",
  "Coordination prestataires",
  "Conception supports",
  "Communication digitale",
  "Budgétisation",
  "Planning communication",
  "Analyse résultats",
  "Briefs créatifs",
  "Relations médias",

 # Graphiste
  "Adobe Creative Suite",
  "Création graphique",
  "Mise en page",
  "Identité visuelle",
  "Typographie",
  "Illustration",
  "Retouche photo",
  "Charte graphique",
  "Prépresse",
  "Design web",

 # Webdesigner
  "Web design",
  "UI/UX design",
  "HTML/CSS",
  "Responsive design",
  "Prototypage",
  "Wireframing",
  "Adobe XD/Figma/Sketch",
  "Ergonomie web",
  "WordPress",
  "Création graphique web",

 # Technicien Audiovisuel
  "Prise de vue",
  "Prise de son",
  "Montage vidéo",
  "Éclairage",
  "Régie",
  "Installation matériel",
  "Maintenance équipement",
  "Post-production",
  "Encodage",
  "Sonorisation",

 # Photographe
  "Prise de vue photo",
  "Retouche photo",
  "Éclairage studio",
  "Logiciels photo",
  "Composition",
  "Photographie événementielle",
  "Portrait",
  "Post-production photo",
  "Direction artistique",
  "Gestion archives photo",

 # Assistant Photographe
  "Préparation matériel",
  "Assistance éclairage",
  "Logistique photo",
  "Organisation shooting",
  "Tri photos",
  "Post-production simple",
  "Relation modèles",
  "Organisation archives",
  "Préparation studio",
  "Relation clients",

 # Conseiller en Voyages
  "Vente séjours",
  "Conseil destinations",
  "Réservation",
  "GDS (Amadeus)",
  "Produits touristiques",
  "Formalités voyage",
  "Relation clients",
  "Devis voyage",
  "Suivi dossiers",
  "Veille destinations",

 # Agent d'Accueil Touristique
  "Accueil visiteurs",
  "Information touristique",
  "Promotion territoire",
  "Réservation activités",
  "Connaissance locale",
  "Langues étrangères",
  "Billetterie",
  "Documentation",
  "Gestion base de données",
  "Statistiques fréquentation",

 # Assistant Manager Hôtelier
  "Coordination services hôtel",
  "Administration hôtelière",
  "Relation clients",
  "Gestion réservations",
  "Supervision housekeeping",
  "Gestion réclamations",
  "Reporting hôtelier",
  "Revenue management",
  "Contrôle qualité",
  "Organisation événements",

 # Chef de Rang
  "Service restauration",
  "Accueil clients restaurant",
  "Organisation salle",
  "Management commis",
  "Prise de commande",
  "Connaissance vins",
  "Techniques de service",
  "Gestion encaissements",
  "Préparation salle",
  "Relation cuisine/salle",

 # Enseignant-Chercheur en Informatique
  "Enseignement informatique",
  "Recherche informatique",
  "Publications scientifiques",
  "Direction thèses",
  "Montage projets recherche",
  "Algorithmique avancée",
  "Intelligence artificielle",
  "Développement logiciel",
  "Systèmes d'information",
  "Evaluation étudiants",

 # Directeur R&D Informatique
  "Stratégie R&D",
  "Management équipe R&D",
  "Innovation technologique",
  "Gestion portefeuille projets",
  "Budgétisation R&D",
  "Partenariats technologiques",
  "Propriété intellectuelle",
  "Veille technologique",
  "Transfer technologique",
  "Roadmap produit",

 # Enseignant-Chercheur en Mathématiques
  "Enseignement mathématiques",
  "Recherche mathématique",
  "Publications académiques",
  "Direction thèses",
  "Modélisation mathématique",
  "Algèbre/Analyse/Géométrie",
  "Statistiques avancées",
  "Théorie des probabilités",
  "Mathématiques appliquées",
  "Évaluation étudiants",

 # Cryptologue
  "Cryptographie",
  "Algorithmes cryptographiques",
  "Sécurité informatique",
  "Analyse de vulnérabilités",
  "Conception protocoles",
  "Mathématiques discrètes",
  "Test d'intrusion",
  "Analyse cryptanalytique",
  "Programmation sécurisée",
  "Blockchain",

 # Enseignant-Chercheur en Physique
  "Enseignement physique",
  "Recherche physique",
  "Expérimentation",
  "Modélisation physique",
  "Publications scientifiques",
  "Direction laboratoire",
  "Physique quantique/théorique",
  "Instrumentation",
  "Analyse de données",
  "Simulations numériques",

 # Ingénieur de Recherche
  "Conception expérimentale",
  "Direction technique",
  "Prototypage",
  "Développement de méthodes",
  "Analyse de données avancée",
  "Rédaction scientifique",
  "Gestion projets R&D",
  "Instruments scientifiques",
  "Validation méthodes",
  "Veille scientifique",

 # Enseignant-Chercheur en Chimie
  "Enseignement chimie",
  "Recherche chimique",
  "Chimie organique/inorganique",
  "Chimie physique",
  "Synthèse chimique",
  "Analyse chimique",
  "Direction thèses",
  "Publications scientifiques",
  "Laboratoire chimie",
  "Évaluation étudiants",

 # Directeur R&D Chimie
  "Management R&D chimie",
  "Stratégie innovation",
  "Développement produits",
  "Gestion projets chimie",
  "Scale-up",
  "Partenariats R&D",
  "Propriété intellectuelle",
  "Réglementation chimie",
  "Budgétisation R&D",
  "Veille technologique",

 # Enseignant-Chercheur
  "Enseignement supérieur",
  "Recherche académique",
  "Publications",
  "Encadrement doctoral",
  "Montage projets",
  "Direction scientifique",
  "Évaluation étudiants",
  "Conférences scientifiques",
  "Comités scientifiques",
  "Expertise disciplinaire",

 # Directeur Innovation
  "Stratégie innovation",
  "Management innovation",
  "Open innovation",
  "Design thinking",
  "Transformation digitale",
  "Gestion portefeuille projets",
  "Partenariats innovation",
  "Business model innovation",
  "Financement innovation",
  "Transfert technologique",

 # Chercheur en Environnement
  "Écologie",
  "Biologie environnementale",
  "Pollution",
  "Biodiversité",
  "Changement climatique",
  "Écotoxicologie",
  "Modélisation environnementale",
  "Biostatistiques",
  "Publications environnementales",
  "Expérimentation terrain",

 # Consultant Expert Environnemental
  "Études impact environnemental",
  "Due diligence environnementale",
  "Psychologie cognitive",
  "Recherche clinique",

 # Directeur de Recherche en Psychologie
  "Direction équipe psychologie",
  "Stratégie recherche psy",
  "Financement recherche",
  "Partenariats académiques",
  "Évaluation chercheurs",
  "Publications haut niveau",
  "Supervision doctorale",
  "Comités scientifiques",
  "Recherche appliquée",
  "Développement laboratoire",

 # Sociologue Chercheur
  "Recherche sociologique",
  "Théories sociologiques",
  "Méthodes qualitatives",
  "Sociologie quantitative",
  "Analyse sociale",
  "Enquêtes terrain",
  "Publications sociologie",
  "Sociologie urbaine/rurale",
  "Analyse de discours",
  "Sociologie des organisations",

 # Expert en Analyse Sociétale
  "Analyse tendances sociales",
  "Prospective sociétale",
  "Analyse d'impact social",
  "Conseil stratégique",
  "Politiques publiques",
  "Développement territorial",
  "Cohésion sociale",
  "Innovation sociale",
  "Évaluation dispositifs",
  "Diagnostic territorial",

 # Historien Chercheur
  "Recherche historique",
  "Archives",
  "Historiographie",
  "Paléographie",
  "Histoire sociale/politique/culturelle",
  "Analyse sources",
  "Publications histoire",
  "Périodisation",
  "Histoire comparée",
  "Méthodes quantitatives histoire",

 # Conservateur en Chef
  "Direction conservation",
  "Politique patrimoniale",
  "Gestion collections",
  "Conservation préventive",
  "Commissariat exposition",
  "Acquisition œuvres",
  "Partenariats culturels",
  "Politique scientifique",
  "Médiation culturelle",
  "Administration musée",

 # Géographe Chercheur
  "Géographie humaine/physique",
  "Analyse spatiale",
  "SIG avancé",
  "Cartographie thématique",
  "Télédétection",
  "Analyse territoriale",
  "Publications géographie",
  "Géomorphologie",
  "Géographie urbaine",
  "Développement durable",

 # Expert en Aménagement du Territoire
  "Planification territoriale",
  "Urbanisme stratégique",
  "Politiques territoriales",
  "Prospective spatiale",
  "Développement régional",
  "Mobilité durable",
  "Projets urbains",
  "Consultation publique",
  "Stratégies métropolitaines",
  "Évaluation impacts",

 # Économiste Chercheur
  "Recherche économique",
  "Modélisation économétrique",
  "Théorie économique",
  "Macroéconomie avancée",
  "Économie internationale",
  "Publications économie",
  "Analyse politique économique",
  "Économie du développement",
  "Économie industrielle",
  "Séries temporelles",

 # Consultant Expert en Économie
  "Analyse économique",
  "Prévisions économiques",
  "Études sectorielles",
  "Stratégie économique",
  "Modélisation économique",
  "Benchmarking international",
  "Intelligence économique",
  "Politiques publiques",
  "Analyse concurrentielle",
  "Rapports économiques",

 # Enseignant-Chercheur en Gestion
  "Enseignement gestion",
  "Recherche management",
  "Publications gestion",
  "Stratégie d'entreprise",
  "Théories organisationnelles",
  "Finance d'entreprise",
  "Marketing stratégique",
  "GRH",
  "Direction thèses",
  "Management international",

 # Consultant Stratégique
  "Conseil stratégique",
  "Analyse concurrentielle",
  "Due diligence",
  "Transformation entreprise",
  "Business development",
  "Optimisation processus",
  "Management du changement",
  "Conseil exécutif",
  "Benchmarking",
  "Modèles économiques",

 # Politologue
  "Science politique",
  "Relations internationales",
  "Systèmes politiques",
  "Analyse électorale",
  "Gouvernance",
  "Politiques publiques",
  "Idéologies politiques",
  "Géopolitique",
  "Publications politique",
  "Analyse institutionnelle",

 # Conseiller Politique
  "Stratégie politique",
  "Analyse politique",
  "Rédaction discours",
  "Communication politique",
  "Affaires publiques",
  "Conseil stratégique",
  "Relations institutionnelles",
  "Gestion de crise",
  "Positionnement politique",
  "Veille politique",

 # Professeur de Droit
  "Enseignement juridique",
  "Recherche juridique",
  "Publications droit",
  "Doctrine juridique",
  "Direction thèses",
  "Analyse jurisprudence",
  "Droit comparé",
  "Évaluation étudiants",
  "Comités scientifiques",
  "Expertise juridique",

 # Juriste Expert
  "Conseil juridique spécialisé",
  "Contentieux complexe",
  "Arbitrage",
  "Négociation juridique",
  "Due diligence juridique",
  "Droit des affaires",
  "Propriété intellectuelle",
  "Droit international",
  "Conformité réglementaire",
  "Stratégie juridique",

 # Philosophe
  "Philosophie morale/politique",
  "Histoire de la philosophie",
  "Épistémologie",
  "Métaphysique",
  "Publications philosophiques",
  "Enseignement philosophie",
  "Analyse conceptuelle",
  "Philosophie contemporaine",
  "Conférences philosophiques",
  "Direction recherche",

 # Éthicien
  "Éthique appliquée",
  "Bioéthique",
  "Comités d'éthique",
  "Analyse dilemmes éthiques",
  "Conseil éthique",
  "Éthique professionnelle",
  "Éthique des affaires",
  "Éthique numérique",
  "Éthique de la recherche",
  "RSE",

 # Professeur de Littérature
  "Enseignement littérature",
  "Analyse littéraire",
  "Critique textuelle",
  "Histoire littéraire",
  "Théorie littéraire",
  "Publications littéraires",
  "Direction thèses",
  "Littérature comparée",
  "Évaluation étudiants",
  "Analyse stylistique",

 # Critique Littéraire
  "Analyse critique",
  "Recension d'ouvrages",
  "Essais critiques",
  "Théorie critique",
  "Histoire littéraire",
  "Création littéraire",
  "Rédaction critique",
  "Courants littéraires",
  "Esthétique littéraire",
  "Publications spécialisées",

 # Linguiste
  "Linguistique générale",
  "Phonologie",
  "Syntaxe",
  "Sémantique",
  "Analyse du discours",
  "Sociolinguistique",
  "Linguistique computationnelle",
  "Publications linguistiques",
  "Terrain linguistique",
  "Typologie linguistique",

 # Expert en Communication Interculturelle
  "Communication interculturelle",
  "Management interculturel",
  "Médiation culturelle",
  "Formation interculturelle",
  "Intelligence culturelle",
  "Négociation internationale",
  "Diversité culturelle",
  "Relations internationales",
  "Adaptation interculturelle",
  "Compétences interculturelles",

 # Chercheur en Arts
  "Histoire de l'art",
  "Théorie esthétique",
  "Analyse œuvres",
  "Critique artistique",
  "Publications arts",
  "Mouvements artistiques",
  "Sociologie de l'art",
  "Archives artistiques",
  "Méthodologie recherche",
  "Commissariat",

 # Conservateur de Musée
  "Conservation préventive",
  "Gestion collections",
  "Exposition",
  "Documentation muséale",
  "Acquisition œuvres",
  "Régie des œuvres",
  "Scénographie",
  "Médiation culturelle",
  "Inventaire",
  "Histoire de l'art",

 # Chercheur en Cinéma
  "Histoire du cinéma",
  "Théorie filmique",
  "Analyse filmique",
  "Esthétique cinématographique",
  "Publications cinéma",
  "Archives film",
  "Genres cinématographiques",
  "Courants cinématographiques",
  "Narratologie filmique",
  "Cinéma comparé",

 # Critique Cinématographique
  "Analyse film",
  "Critique de film",
  "Histoire cinéma",
  "Théorie cinématographique",
  "Rédaction critique",
  "Festival film",
  "Entretiens cinéastes",
  "Publications spécialisées",
  "Conférences cinéma",
  "Courants cinématographiques",

 # Musicologue
  "Histoire de la musique",
  "Analyse musicale",
  "Théorie musicale",
  "Ethnomusicologie",
  "Publications musicologiques",
  "Paléographie musicale",
  "Organologie",
  "Archives sonores",
  "Édition critique",
  "Recherche musicologique",

 # Directeur Musical
  "Direction musicale",
  "Direction d'orchestre",
  "Programmation musicale",
  "Interprétation",
  "Répétition",
  "Gestion musiciens",
  "Conseil artistique",
  "Production musicale",
  "Arrangement",
  "Connaissance répertoire",

 # Architecte Chercheur
  "Théorie architecturale",
  "Histoire architecture",
  "Publications architecture",
  "Analyse architecturale",
  "Urbanisme théorique",
  "Développement durable",
  "Méthodologie recherche",
  "Critique architecturale",
  "Prospective architecturale",
  "Design research",

 # Expert en Patrimoine Architectural
  "Conservation patrimoine",
  "Restauration monuments",
  "Diagnostic patrimonial",
  "Législation patrimoine",
  "Inventaire architectural",
  "Valorisation patrimoine",
  "Expertise technique",
  "Conseil conservation",
  "Médiation patrimoniale",
  "Histoire de l'architecture",

    "Python",
    "SQL",
    "Gestion de projet",
    "Analyse de données",
    "Communication",
    "Conception de circuits électriques",
    "Dimensionnement d'installations électriques",
    "Maîtrise des logiciels CAO électrique (EPLAN, AutoCAD Electrical)",
    "Conception de systèmes d'automatisme",
    "Schématique électrique",
    "Conception de PCB (circuits imprimés)",
    "Protection des installations électriques",
    "Conception d'armoires électriques",
    "Calcul de chutes de tension et dimensionnement de câbles",
    "Conception d'installations BT/HT",
    "Distribution électrique",
    "Conception de réseaux de distribution",
    "Étude de sélectivité des protections",
    "Compensation d'énergie réactive",
    "Stabilité des réseaux électriques",
    "Smart grids et réseaux intelligents",
    "Gestion technique centralisée (GTC)",
    "Supervision électrique (SCADA)",
    "Qualité et filtrage des harmoniques",
    "Continuité de service électrique",
    "Dimensionnement de groupes électrogènes",
    "Conception de systèmes électroniques",
    "Développement de cartes électroniques",
    "Programmation de microcontrôleurs",
    "Électronique de puissance",
    "Convertisseurs statiques (AC/DC, DC/DC)",
    "Systèmes embarqués temps réel",
    "Compatibilité électromagnétique (CEM)",
    "Test et validation de systèmes électroniques",
    "Prototypage électronique",
    "IoT et systèmes connectés",
    "Programmation d'automates (PLC)",
    "Systèmes SCADA et IHM",
    "Instrumentation industrielle",
    "Régulation PID et contrôle de processus",
    "Bus de terrain et protocoles industriels",
    "Variateurs de vitesse et motion control",
    "Systèmes de sécurité machine",
    "Supervision et télémaintenance",
    "Robotique industrielle",
    "Traitement de signal et acquisition de données",
    "Conception de systèmes photovoltaïques",
    "Éolien et systèmes de conversion",
    "Stockage d'énergie électrique",
    "Audits énergétiques",
    "Smart building et domotique",
    "Efficacité énergétique des installations",
    "Gestion de la charge électrique",
    "Mobilité électrique et bornes de recharge",
    "Micro-grids et réseaux autonomes",
    "Monitoring et optimisation de consommation",
    "Conception de pièces et systèmes mécaniques",
    "Maîtrise des logiciels CAO (CATIA, SolidWorks, Inventor)",
    "Dimensionnement et calcul de résistance des matériaux",
    "Conception de mécanismes et cinématique",
    "Modélisation 3D et assemblage virtuel",
    "Conception pour la fabrication (DFM)",
    "Analyse par éléments finis (FEA)",
    "Tolérancement géométrique (GD&T)",
    "Conception de moules et outillages",
    "Analyse de défaillance mécanique",
    "Procédés d'usinage conventionnel (fraisage, tournage)",
    "Usinage à commande numérique (CNC)",
    "Techniques de soudage et assemblage",
    "Fabrication additive et impression 3D",
    "Techniques de fonderie et moulage",
    "Formage et emboutissage de métaux",
    "Prototypage rapide",
    "Métrologie et contrôle dimensionnel",
    "Traitement thermique des métaux",
    "Programmation de machines-outils",
    "Science des matériaux métalliques",
    "Composites et polymères techniques",
    "Tribologie et étude des frottements",
    "Comportement mécanique des matériaux",
    "Fatigue et rupture des matériaux",
    "Corrosion et protection des surfaces",
    "Dynamique des structures",
    "Vibrations mécaniques",
    "Élasticité et plasticité",
    "Mécanique des fluides appliquée",
    "Maintenance prédictive et préventive",
    "Analyse vibratoire des machines tournantes",
    "Thermographie infrarouge",
    "Diagnostics de pannes mécaniques",
    "Gestion de maintenance assistée par ordinateur (GMAO)",
    "Analyse des modes de défaillance (AMDEC)",
    "Fiabilité des systèmes mécaniques",
    "Tribologie et lubrification industrielle",
    "Alignement laser et équilibrage",
    "Retrofitting de machines industrielles",
    "Simulation numérique des écoulements (CFD)",
    "Dynamique multi-corps",
    "Optimisation topologique",
    "Simulation de processus d'usinage",
    "Modélisation thermique",
    "Calcul de durée de vie en fatigue",
    "Analyse modale et acoustique",
    "Simulation d'impacts et crash tests",
    "Validation expérimentale de modèles",
    "Jumeaux numériques de systèmes mécaniques",
    "Gestion de lignes de production",
    "Optimisation des processus industriels",
    "Lean Manufacturing",
    "Six Sigma et amélioration continue",
    "Planification de production (MRP, MRPII)",
    "Gestion des approvisionnements et stocks",
    "Contrôle qualité et assurance qualité",
    "Organisation d'ateliers de production",
    "Expertise en méthodes et industrialisation",
    "Conception de systèmes automatisés",
    "Programmation d'automates industriels (PLC)",
    "Robotique industrielle et cobotique",
    "Maîtrise des SCADA et systèmes de supervision",
    "Conception de machines spéciales",
    "Ingénierie mécanique",
    "Électrotechnique industrielle",
    "Ingénierie des procédés",
    "Conception assistée par ordinateur (CAO)",
    "Simulation numérique de processus",
    "Internet des objets industriel (IIoT)",
    "Jumeaux numériques (Digital Twins)",
    "Réalité augmentée pour maintenance",
    "Big data industriel et analytics",
    "Intelligence artificielle appliquée à la production",
    "Cloud computing industriel",
    "Cybersécurité des systèmes industriels",
    "Edge computing en environnement industriel",
    "Blockchain pour la traçabilité industrielle",
    "Supply chain management",
    "Gestion de projets industriels",
    "Analyse des coûts de production",
    "Kaizen et méthodes d'amélioration continue",
    "Management visuel et 5S",
    "Gestion des flux (Value Stream Mapping)",
    "Analyse de la valeur et réduction des coûts",
    "Total Productive Maintenance (TPM)",
    "Gestion des systèmes qualité (ISO 9001)",
    "Overall Equipment Effectiveness (OEE)",
    "Expertise en normes HSE (Hygiène, Sécurité, Environnement)",
    "Gestion des risques industriels",
    "Économie circulaire et éco-conception",
    "Efficacité énergétique industrielle",
    "Réduction de l'empreinte carbone",
    "Gestion des déchets industriels",
    "Normes ISO 14001 et 45001",
    "Sécurité des machines et équipements",
    "Analyse des risques AMDEC/FMEA",
    "Prévention des accidents industriels",
    "Analyse des états financiers",
    "Comptabilité générale et analytique",
    "Normes IFRS/US GAAP",
    "Consolidation financière",
    "Audit financier interne/externe",
    "Reporting financier",
    "Contrôle de gestion",
    "Élaboration de budgets prévisionnels",
    "Analyse des écarts budgétaires",
    "Calcul des ratios financiers",
    "Évaluation d'entreprise (DCF, multiples)",
    "Optimisation de la structure de capital",
    "Gestion de trésorerie",
    "Planification financière stratégique",
    "Fusion-acquisition (M&A)",
    "Due diligence financière",
    "Modélisation financière complexe",
    "Finance de projet",
    "Gestion des risques d'entreprise",
    "Restructuration financière",
    "Analyse technique et fondamentale",
    "Trading algorithmique",
    "Construction et gestion de portefeuille",
    "Évaluation d'actifs financiers",
    "Gestion de fonds d'investissement",
    "Analyse quantitative (quant)",
    "Stratégies de couverture (hedging)",
    "Produits dérivés et structurés",
    "Gestion actif-passif (ALM)",
    "Finance comportementale",
    "Blockchain et crypto-actifs",
    "Automatisation des processus financiers (RPA)",
    "Big data et analytics financiers",
    "Intelligence artificielle appliquée à la finance",
    "Systèmes d'information financière (ERP, BI)",
    "Modélisation de risque avec Machine Learning",
    "Cybersécurité des données financières",
    "Connaissance des régulations bancaires (Bâle III/IV)",
    "Lutte anti-blanchiment (LAB/LCB)",
    "Conformité MiFID II/EMIR",
    "Reporting réglementaire (SFTR, PRIIPS)",
    "GDPR appliquée aux données financières",
    "Contrôle interne et conformité",
    "ESG et finance durable",
    "Gestion de patrimoine et conseil financier",
    "Finance internationale et gestion du risque de change",
    "Private equity et capital-risque",
    "Valorisation d'actifs immatériels",
    "Communication financière",
    "Conception structurelle de bâtiments",
    "Calcul de résistance des matériaux",
    "Gestion de projets de construction",
    "Expertise en géotechnique et fondations",
    "Conception d'infrastructures routières",
    "Conception de réseaux hydrauliques et d'assainissement",
    "Modélisation BIM (Building Information Modeling)",
    "Supervision de chantiers",
    "Analyse de la durabilité des structures",
    "Conception parasismique",
    "Planification urbaine",
    "Aménagement d'espaces publics",
    "Conception de quartiers durables",
    "Réhabilitation de zones urbaines",
    "Élaboration de plans locaux d'urbanisme",
    "Études d'impact environnemental",
    "Cartographie et systèmes d'information géographique (SIG)",
    "Conception de mobilité urbaine",
    "Gestion des ressources en eau",
    "Traitement des eaux usées",
    "Études de pollution des sols",
    "Certification environnementale de bâtiments (HQE, LEED, BREEAM)",
    "Évaluation de l'empreinte carbone",
    "Conception bioclimatique",
    "Gestion des déchets de construction",
    "Analyse du cycle de vie des matériaux",
    "Maîtrise des normes de construction (Eurocodes)",
    "Rédaction de cahiers des charges techniques",
    "Gestion des appels d'offres",
    "Suivi financier de projets",
    "Expertise en pathologie du bâtiment",
    "Diagnostic technique immobilier",
    "Coordination sécurité et protection de la santé",
    "Maîtrise de la réglementation thermique",
    "Maîtrise des logiciels de CAO/DAO (AutoCAD, Revit)",
    "Modélisation 3D et rendus architecturaux",
    "Utilisation de logiciels de calcul de structures",
    "Simulation thermique dynamique",
    "Maîtrise des outils de gestion de projet (MS Project, Primavera)",
    "Utilisation de drones pour l'inspection d'ouvrages",
    "Numérisation laser et photogrammétrie",
    "Coordination inter-disciplinaire (architectes, bureaux d'études)",
    "Estimation des coûts de construction",
    "Planification et ordonnancement de travaux",
    "Gestion des contrats de construction",
    "Évaluation des risques de projet",
    "Management d'équipes techniques pluridisciplinaires",
    "Médiation et résolution de conflits techniques",
    "Expertise judiciaire en construction",
    "Audits techniques de bâtiments existants",
    "Gestion de campagnes SEO/SEM",
    "Expertise Google Analytics et outils de mesure d'audience",
    "Marketing automation (HubSpot, Marketo, Mailchimp)",
    "Growth hacking et acquisition de trafic",
    "Marketing de contenu et storytelling",
    "Réalisation de campagnes d'emailing",
    "Stratégie d'Inbound Marketing",
    "Maîtrise des plateformes publicitaires (Google Ads, Facebook Ads)",
    "Optimisation du taux de conversion (CRO)",
    "Attribution marketing et ROI",
    "Community management",
    "Stratégie de contenu pour réseaux sociaux",
    "Social media advertising",
    "Gestion de crise sur les réseaux sociaux",
    "Social listening et veille concurrentielle",
    "Création de contenu viral",
    "Gestion de l'identité numérique et e-réputation",
    "Influence marketing et relations KOLs",
    "Relations presse et relations publiques",
    "Rédaction de communiqués de presse",
    "Organisation d'événements et sponsoring",
    "Communication interne et corporate",
    "Communication de crise",
    "Communication institutionnelle",
    "Stratégie de marque et positionnement",
    "Création de supports de communication",
    "Direction artistique et identité visuelle",
    "Design graphique (Adobe Creative Suite)",
    "UX/UI Design pour interfaces digitales",
    "Production de contenu multimédia (photo, vidéo)",
    "Motion design et animations",
    "Infographie et data visualization",
    "Conception de chartes graphiques",
    "Élaboration de plans marketing",
    "Analyse de données marketing et business intelligence",
    "Études de marché et panels consommateurs",
    "Segmentation et ciblage",
    "Benchmarking concurrentiel",
    "Définition de personas et parcours client",
    "Création de tableaux de bord marketing",
    "Gestion de gamme et pricing",
    "Product marketing et lancement de produits",
    "Marketing B2B et lead generation",
    "Expérience client et satisfaction client",
    "Merchandising et marketing point de vente",
    "CRM et fidélisation client",
    "Référencement produit et marketplaces",
    "Programmation en Python",
    "Développement JavaScript/TypeScript",
    "Maîtrise de React/Angular/Vue.js",
    "Développement backend avec Node.js",
    "Maîtrise du langage Java",
    "Développement mobile (iOS/Android)",
    "Architecture microservices",
    "Clean Code & refactoring",
    "Tests unitaires et d'intégration",
    "Développement orienté API REST/GraphQL",
    "Gestion d'infrastructures AWS/Azure/GCP",
    "Conteneurisation avec Docker",
    "Orchestration Kubernetes",
    "Automatisation CI/CD (Jenkins, GitHub Actions)",
    "Infrastructure as Code (Terraform, CloudFormation)",
    "Monitoring et observabilité (Prometheus, Grafana)",
    "Gestion de configuration (Ansible, Chef, Puppet)",
    "Cloud-native development",
    "Ingénierie de données (ETL/ELT)",
    "Administration bases de données SQL/NoSQL",
    "Data warehousing (Snowflake, BigQuery)",
    "Machine Learning et modèles prédictifs",
    "Traitement big data (Spark, Hadoop)",
    "Streaming de données (Kafka, Kinesis)",
    "Visualisation de données (Tableau, PowerBI)",
    "NLP (Natural Language Processing)",
    "Tests d'intrusion (pentest)",
    "Analyse de vulnérabilités",
    "Réponse aux incidents de sécurité",
    "Sécurité cloud",
    "Cryptographie appliquée",
    "Développement sécurisé (DevSecOps)",
    "Identity & Access Management (IAM)",
    "Administration Linux/Windows",
    "Virtualisation (VMware, Proxmox)",
    "Configuration réseaux (Cisco, Juniper)",
    "Architectures haute disponibilité",
    "SD-WAN et réseaux programmables",
    "Stockage et sauvegarde (SAN/NAS)",
    "Téléphonie IP et communications unifiées",
    "Méthodologies agiles (Scrum, Kanban)",
    "Management d'équipes techniques",
    "Rédaction de documentation technique",
    "Communication client et vulgarisation technique",
    "Gestion de budgets IT",
    "Analyse de risques",
    "Leadership technique et mentoring",
    "Gestion de crises IT",
    "Veille technologique",
    "Intelligence émotionnelle et résolution de conflits",
    "Pensée critique et analytique",
"Créativité et innovation",
"Résolution de problèmes complexes (approche systémique)",
"Adaptabilité et flexibilité cognitive",
"Gestion du stress et résilience",
"Prise de décision éthique et responsable",
"Collaboration et travail en équipe multiculturelle",
"Curiosité intellectuelle et soif d'apprendre (Learnability)",
"Persévérance et courage managérial",
"Négociation et persuasion (avancé)",
"Prise de parole en public et éloquence",
"Pédagogie et mentorat (au-delà du technique)",
"Empathie active et écoute profonde",
"Gestion du temps et priorisation stratégique",
"Assertivité et affirmation de soi constructive",
"Sens du service client et orientation usager",
"Intelligence culturelle et adaptabilité interculturelle",
"Capacité à donner et recevoir du feedback constructif",
"Autonomie et proactivité",
"Rigueur et souci du détail",
"Esprit d'initiative et intrapreneuriat",
"Optimisme et pensée positive",
"Diplomatie et tact",
"Patience et maîtrise de soi",
"Faculté d'observation et d'analyse contextuelle",
"Capacité de synthèse et de vulgarisation (avancé)",
"Vision stratégique et prospective",
"Gestion du changement et accompagnement des transitions",
"Humilité intellectuelle",
"Facilitation de groupes et d'ateliers participatifs",
"Storytelling (appliqué à divers contextes)",
"Gestion de conflits multipartites",
"Auto-évaluation et développement personnel continu",
"Sens de l'organisation personnelle et collective",
"Influence et leadership situationnel",
"Anglais des affaires (C1/C2)",
"Allemand professionnel (secteur spécifique)",
"Espagnol technique (documentation, support)",
"Italien (mode, luxe, design)",
"Chinois Mandarin (négociation commerciale)",
"Japonais (technologie, culture)",
"Arabe (commerce international, diplomatie)",
"Portugais (Brésil, pays lusophones)",
"Russe (énergie, sciences)",
"Néerlandais (logistique, commerce européen)",
"Coréen (technologie, divertissement)",
"Langue des Signes Française (LSF)",
"Langue des Signes Américaine (ASL)",
"Suédois/Norvégien/Danois (design, technologie verte)",
"Hindi (services IT, commerce)",
"Traduction technique spécialisée (domaine X vers Y)",
"Interprétation de conférence (simultanée, consécutive)",
"Rédaction technique multilingue",
"Localisation de logiciels et sites web",
"Concevoir des supports de communication et d'image",
"Réaliser un montage son ou vidéo",
"Concevoir et réaliser des éléments graphiques et visuels",
"Concevoir et réaliser un jeu vidéo",
"Diffuser du son, de la video, de l'audiovisuel",
"Écrire ou modifier une oeuvre littéraire (roman, nouvelle, scénario…)",
"Créer un son, une œuvre musicale",
"Orchestrer une oeuvre musicale",
"Mettre en scène un spectacle",
"Réaliser un film, une émission, un programme",
"Créer, écrire une chorégraphie",
"Réaliser une oeuvre plastique (peinture, sculpture...)",
"Porter une appréciation esthétique ou artistique",
"Définir un style ou une direction artistique dans les domaines de l'art, la mode ou le design",
"Concevoir un objet d'art ou d'artisanat",
"Poser pour une oeuvre, défiler",
"Danser, interpréter une chorégraphie",
"Interpréter une oeuvre, un spectacle ou un numéro",
"Interpréter un rôle dans les domaines de l'art du spectacle ou de l'audiovisuel",
"Filmer, photographier",
"Mixer des morceaux de musique",
"Maîtriser l'usage d'un instrument de musique",
"Administrer une enquête, un sondage",
"Concevoir un questionnaire, un support d'enquête",
"Réaliser une étude d'opportunité et de faisabilité technique et économique",
"Réaliser une étude d'ergonomie, analyser les usages",
"Concevoir des maquettes et pré-maquettes",
"Concevoir un ouvrage",
"Concevoir un algorithme",
"Concevoir et faire évoluer un modèle, un prototype",
"Concevoir une formule technique, un modèle théorique",
"Créer, concevoir de nouveaux produits ou des améliorations produits",
"Créer, concevoir de nouveaux services ou des améliorations de services",
"Créer, élaborer et identifier des concepts innovants",
"Collecter, tester, analyser des échantillons, des matériaux",
"Observer des faits, des évènements, des comportements",
"Procéder à des tests, expérimentations",
"Réaliser une veille technique ou technologique pour anticiper les évolutions",
"Analyser, résoudre un problème courant ou complexe",
"Élaborer une stratégie de résolution de problèmes",
"Concevoir et animer une démarche d'innovation",
"Conduire des travaux d'études et de recherche",
"Concevoir un logiciel, un système d'informations, une application",
"Concevoir l'architecture d'un système, d'un réseau",
"Paramétrer un logiciel, un outil, un système numérique",
"Développer un logiciel, un système d'informations, une application",
"Déployer, intégrer un logiciel, un système d'informations, une application",
"Administrer un système d'informations",
"Exploiter des solutions de Data Science ou d'Intelligence Artificielle",
"Intégrer des produits Data dans les processus métiers",
"Utiliser des logiciels spécifiques",
"Analyser, exploiter, structurer des données",
"Réaliser une analyse ou modélisation statistique de données",
"Créer un dessin technique, un plan, ou une carte",
"Comprendre, interpréter des données et documents techniques",
"Renseigner, mettre à jour une documentation technique",
"Créer une documentation technique",
"Contrôler la conformité des données",
"Gérer une base de données numériques",
"Analyser une situation et produire un diagnostic",
"Définir et faire évoluer des procédés de traitement de l'information",
"Analyser / traiter l'information à des fins d'anticipation",
"Mettre à jour un dossier, une base de données",
"Réaliser et vérifier des calculs de mathématiques généraux ou appliqués",
"Élaborer des processus et des modes opératoires techniques",
"Élaborer et planifier un programme de production, d'exploitation",
"Réaliser l'aménagement technique d'un espace de travail",
"Concevoir, améliorer un équipement, une machine, une installation",
"Concevoir des coulages et moulages des matières premières",
"Concevoir, fabriquer un outil technique",
"Concevoir un appareillage médical",
"Élaborer un schéma directeur technique, définir des besoins en équipement",
"Installer, mettre en oeuvre des réalisations de gros oeuvre",
"Installer, mettre en oeuvre des réalisations de second oeuvre",
"Réaliser des travaux de terrassement, de fondations",
"Raccorder, gérer un réseau technique",
"Réaliser des ouvrages de maçonnerie",
"Réaliser des travaux de construction et de maintenance en mécanique",
"Réaliser des ouvrages de menuiserie",
"Réaliser, poser des revêtements",
"Réaliser des ouvrages d'isolation",
"Fixer, poser, installer des éléments, des ouvrages",
"Équiper techniquement des bâtiments, installations, et véhicules",
"Réviser des documents ou procédures",
"Entretenir, nettoyer un produit ou du matériel",
"Effectuer les opérations de réparation",
"Entretenir un équipement, une machine, une installation",
"Réaliser des corrections ou réparations sur un ouvrage",
"Contrôler la conformité d'un équipement, d'une machine, d'une installation",
"Réparer un équipement, une machine, une installation",
"Réaliser une opération de maintenance",
"Réaliser un diagnostic technique",
"Assurer la maintenance, gérer une structure",
"Entretenir un véhicule",
"Entretenir, nettoyer un espace, un lieu, un local",
"Surveiller un espace, un local, un lieu, une installation",
"Aménager un espace physique de stockage",
"Rénover, moderniser, réhabiliter des installations",
"Gérer un parc de machines, d'équipements, de locaux",
"Contrôler le fonctionnement d'un équipement, d'une machine, d'une installation",
"Organiser ou surveiller des phases de fabrication",
"Superviser des opérations, des actions",
"Déterminer des mesures correctives",
"Évaluer une situation à risques",
"Élaborer des actions ou des règles de prévention",
"Évaluer, prévenir, et gérer les risques et la sécurité",
"Définir et mettre en oeuvre des protocoles de sécurité",
"Réaliser une analyse des risques liés à une prise en charge médicale",
"Anticiper des dangers, problèmes ou besoins matériels et techniques",
"Piloter la gestion des risques",
"Gérer une situation de crise",
"Élaborer des règles et procédures de Qualité, Hygiène, Sécurité, Santé et Environnement (QHSSE)",
"Piloter une démarche qualité, un processus d'amélioration continue",
"Réaliser un audit technique",
"Analyser la qualité et la conformité des matières premières",
"Analyser la qualité d'un produit",
"Analyser la qualité d'un service",
"Analyser la qualité des process",
"Évaluer la qualité et la conformité d'une formation",
"Contrôler les règles de Qualité, Hygiène, Sécurité, Santé et Environnement (QHSSE)",
"Contrôler la qualité d'une oeuvre, d'un service",
"Contrôler la qualité d'une matière première, d'une ressource",
"Contrôler la qualité et la conformité d'un produit",
"Contrôler la qualité et la conformité d'un livrable",
"Contrôler la qualité et la conformité d'un bâtiment, d'une infrastructure",
"Contrôler la qualité et la conformité des process",
"Participer à un inventaire",
"Gérer les stocks",
"Organiser et contrôler un approvisionnement",
"Trier, ranger des produits, des matières premières",
"Réceptionner des produits, des matières premières, vérifier la conformité d'une livraison",
"Manipuler un engin de manutention ou de chantier",
"Charger, décharger, manutentionner des produits",
"Lever des produits ou du matériel de charge lourde",
"Conditionner des produits",
"Mettre en oeuvre l'organisation matérielle et logistique d'un événement",
"Organiser une opération logistique de transport",
"Réguler, superviser le trafic d'un réseau de transport",
"Organiser le traitement des commandes",
"Organiser une opération logistique industrielle",
"Effectuer une livraison",
"Conduire un véhicule routier",
"Conduire un véhicule ferroviaire",
"Conduire, convoyer un véhicule marin ou fluvial",
"Piloter un aéronef",
    "Avril 2015 - Décembre 2017",
    "Août 2021 - Février 2024",
    "2018-2022",
    "Septembre 2016 - Mars 2019",
    "Janvier 2020 - Juillet 2022",
    "2015-2021",
    "Mai 2017 - Novembre 2019",
    "Décembre 2021 - Présent",
    "2013-2019",
    "Juin 2018 - Février 2021",
    "Octobre 2020 - Avril 2023",
    "2017-2022",
    "Février 2016 - Août 2018",
    "Mars 2022 - Octobre 2024",
    "2014-2020",
    "Novembre 2015 - Mai 2018",
    "Juillet 2020 - Janvier 2023",
    "2016-2022",
    "Avril 2017 - Décembre 2019",
    "Août 2021 - Présent",
    "2018-2024",
    "Septembre 2014 - Mars 2017",
    "Janvier 2020 - Septembre 2022",
    "2015-2023",
    "Mai 2018 - Novembre 2020",
    "Décembre 2022 - Présent"
]

# Fonctions
def generer_telephone():
    return f"06 {random.randint(10, 99)} {random.randint(10, 99)} {random.randint(10, 99)} {random.randint(10, 99)}"

import random

def generer_adresse(ville):
    return f"{random.randint(1, 100)} Rue {random.choice(['de la Paix', 'des Lilas', 'Victor Hugo', 'Jean Jaurès', 'de la Liberté', 'des Acacias', 'Pasteur', 'de l’Égalité', 'des Rosiers', 'Georges Clemenceau', 'du Général Leclerc', 'des Peupliers', 'Émile Zola', 'de la République', 'des Tilleuls', 'Charles de Gaulle', 'des Charmilles', 'Voltaire', 'du Maréchal Foch', 'des Saules', 'Jules Ferry', 'de l’Avenir', 'des Cerisiers', 'Gambetta', 'du Progrès', 'des Érables', 'Louis Pasteur', 'de l’Espoir', 'des Châtaigniers', 'Jean Moulin', 'des Jardins', 'Rousseau', 'du Centenaire', 'des Oliviers', 'Lamartine', 'de l’Union', 'des Glycines', 'Pierre Curie', 'du Souvenir', 'des Bouleaux', 'René Descartes', 'de la Fraternité', 'des Lauriers', 'Marie Curie', 'du Patrimoine', 'des Pins', 'François Mitterrand', 'de l’Indépendance', 'des Vignes', 'André Malraux', 'du Renouveau', 'des Noisetiers', 'Simone Veil'])}, {ville}"


def personnaliser_descriptif(descriptif_base):
    """Personnalise un descriptif en remplaçant les placeholders {} par des valeurs appropriées"""

    # Analyser le descriptif pour déterminer son type
    if "équipe de {} personnes" in descriptif_base or "équipes de {} membres" in descriptif_base or "équipes multidisciplinaires de {} collaborateurs" in descriptif_base or "{} nouveaux talents" in descriptif_base or "{} employés" in descriptif_base:
        # Nombre de personnes dans une équipe
        valeur = random.randint(3, 30)
        return descriptif_base.format(valeur)

    elif "{}K€" in descriptif_base:
        # Budget en milliers d'euros
        valeur = random.randint(10, 500)
        return descriptif_base.format(valeur)

    elif "{}M€" in descriptif_base:
        # Budget en millions d'euros
        valeur = random.randint(1, 50)
        return descriptif_base.format(valeur)

    elif "{}%" in descriptif_base:
        # Pourcentage (augmentation, diminution)
        valeur = random.randint(5, 40)
        return descriptif_base.format(valeur)

    elif "événements {} avec {} participants" in descriptif_base or "événements virtuels {} pour {} utilisateurs" in descriptif_base or "salons professionnels {} attirant {} visiteurs" in descriptif_base or "festivals culturels {} avec {} spectateurs" in descriptif_base:
        # Double placeholder: type d'événement et nombre de participants
        types = ["professionnels", "grand public", "internes", "internationaux", "sectoriels", "thématiques", "corporate"]
        nombre = random.randint(50, 1000)
        return descriptif_base.format(random.choice(types), nombre)

    elif "campagnes digitales {} sur {} réseaux sociaux" in descriptif_base or "campagnes de marketing d'influence {} avec {} créateurs" in descriptif_base or "campagnes de marketing par e-mail {} pour {} abonnés" in descriptif_base:
        # Double placeholder pour campagnes marketing
        types = ["performantes", "ciblées", "virales", "innovantes", "personnalisées", "automatisées"]
        nombre = random.randint(3, 15) if "réseaux sociaux" in descriptif_base else random.randint(10, 100) if "créateurs" in descriptif_base else random.randint(1000, 50000)
        return descriptif_base.format(random.choice(types), nombre)

    elif "réseaux sociaux {} pour {} abonnés" in descriptif_base or "programmes de fidélité {} pour {} utilisateurs" in descriptif_base or "lancements de produits {} sur {} marchés" in descriptif_base:
        # Double placeholder: type et nombre
        types = ["principaux", "stratégiques", "internationaux", "prioritaires", "innovants"]
        nombre = random.randint(1000, 100000) if "abonnés" in descriptif_base else random.randint(500, 10000) if "utilisateurs" in descriptif_base else random.randint(3, 15)
        return descriptif_base.format(random.choice(types), nombre)

    else:
        # Cas général avec un seul placeholder
        complements = [
            "qualité", "performance", "innovation", "développement durable",
            "transformation digitale", "amélioration continue", "service client",
            "internationaux", "nationaux", "régionaux", "stratégiques", "opérationnels",
            "produits innovants", "services personnalisés", "entreprises partenaires",
            "filiales", "institutions", "grands comptes", "PME", "startups",
            "conformité", "haute performance", "optimisation", "excellence"
        ]

        # Vérifier combien de placeholders contient la chaîne
        nb_placeholders = descriptif_base.count("{}")

        if nb_placeholders == 1:
            # Cas simple avec un seul placeholder
            return descriptif_base.format(random.choice(complements))
        else:
            # Cas exceptionnel avec plusieurs placeholders non gérés précédemment
            # Générer plusieurs valeurs aléatoires
            args = []
            for _ in range(nb_placeholders):
                args.append(random.choice(complements))
            return descriptif_base.format(*args)


def generer_cv_avance():
    """Génère un CV réaliste et complexe pour tout type de profil professionnel"""
    # Informations de base
    nom = random.choice(noms)
    prenom, nom_famille = nom.split()
    email = random.choice(emails).format(nom=nom_famille.lower(), prenom=prenom.lower())
    telephone = generer_telephone()
    ville = random.choice(villes)
    adresse = generer_adresse(ville)

    # Section profil (avec variations)
    profil_present = random.choice([True, True, False])  # 2/3 chance d'avoir un profil
    profil = ""
    if profil_present:
        # Liste de domaines professionnels variés
        domaines = [
            "Informatique", "Marketing", "Finance", "Ressources Humaines", "Communication",
            "Droit", "Santé", "Éducation", "Commerce", "Ingénierie", "Architecture",
            "Journalisme", "Recherche", "Sciences Sociales", "Arts et Culture",
            "Hôtellerie", "Tourisme", "Logistique", "Environnement", "Immobilier"
        ]

        # Types de profils variés
        intro_phrases = [
            f"Diplômé(e) d'un {random.choice(['Master', 'Doctorat', 'Diplôme', 'MBA', 'BTS', 'Licence'])} en {random.choice(domaines)}",
            f"Professionnel(le) expérimenté(e) en {random.choice(domaines)}",
            f"{random.choice(['Cadre', 'Consultant(e)', 'Spécialiste', 'Expert(e)'])}, {random.randint(2, 15)} ans d'expérience en {random.choice(domaines)}",
            f"Jeune diplômé(e) en {random.choice(domaines)} avec une forte motivation",
            f"Passionné(e) de {random.choice(domaines)} avec une solide formation"
        ]

        # Objectifs variés
        objectifs = [
            f"À la recherche d'un {random.choice(['CDI', 'CDD', 'poste', 'contrat'])} à temps {random.choice(['plein', 'partiel'])}",
            f"Disponible pour de nouvelles opportunités professionnelles",
            f"Souhaite relever de nouveaux défis dans un environnement {random.choice(['dynamique', 'innovant', 'international', 'stimulant'])}",
            f"En reconversion professionnelle après {random.randint(2, 10)} ans dans le secteur {random.choice(domaines)}",
            f"Vise un poste de {random.choice(['responsable', 'manager', 'directeur', 'chargé(e) de mission'])}"
        ]

        # Construction du profil
        profil = f"Profil\n{random.choice(intro_phrases)}. {random.choice(objectifs)}.\n\n"

    # Formation avec différents formats et variétés
    formation_count = random.randint(1, 4)
    formations_text = "Formation\n"
    formations_entities = []

    etablissements = [
        "Université de", "École de", "Institut de", "Académie de", "Conservatoire de",
        "Faculté de", "École Supérieure de", "Centre de Formation en", "Lycée", "GRETA"
    ]

    for i in range(formation_count):
        annee_fin = 2023 - i
        annee_debut = annee_fin - random.randint(1, 3)
        annee = f"{annee_debut}-{annee_fin}"

        formation = random.choice(formations)
        etablissement = f"{random.choice(etablissements)} {random.choice(villes)}"

        # Varier le format de présentation
        format_type = random.randint(1, 5)
        if format_type == 1:
            formation_str = f"- {formation}, {etablissement}, {annee}\n"
        elif format_type == 2:
            formation_str = f"{annee} : {formation}\n  {etablissement}\n"
        elif format_type == 3:
            formation_str = f"• {formation} ({annee})\n  {etablissement}\n"
        elif format_type == 4:
            formation_str = f"{formation}\n  {etablissement} | {annee}\n"
        else:
            formation_str = f"{annee} | {etablissement}\n  {formation}\n"

        formations_text += formation_str

        # Garder trace de l'entité pour l'annotation
        formation_start = formations_text.find(formation)
        if formation_start != -1:
            formations_entities.append((formation_start, formation_start + len(formation), "FORMATION"))

    formations_text += "\n"

    # Expérience professionnelle avec différents formats et pour différents secteurs
    experience_count = random.randint(1, 5)
    experience_text = "Expérience Professionnelle\n"
    experience_entities = []


    # Descriptifs génériques adaptés à tous types de profils
    descriptifs_generiques = [
        # Gestion / Management
        "Gestion d'une équipe de {} personnes",
        "Élaboration et suivi de budgets annuels de {}K€",
        "Mise en place de procédures {}",
        "Coordination de projets {}",
        "Supervision des opérations de {}",
    "Encadrement d'équipes multidisciplinaires de {} collaborateurs",
    "Motivation d'équipes de {} membres pour atteindre les objectifs",
    "Recrutement et intégration de {} nouveaux talents",
    "Formation continue de {} employés pour développer leurs compétences",
    "Évaluation des performances de {} collaborateurs",
    "Élaboration et suivi de budgets annuels de {}K€",
    "Optimisation de budgets de {}K€ pour maximiser les ressources",
    "Contrôle des coûts sur des projets de {}K€",
    "Prévision budgétaire pour des opérations de {}M€",
    "Mise en place de procédures {} pour standardiser les opérations",
    "Conception de processus {} pour améliorer l'efficacité",
    "Audit de procédures {} pour garantir la conformité",
    "Automatisation de processus {} pour réduire les erreurs",
    "Coordination de projets {} à l'échelle internationale",
    "Pilotage de projets {} avec des équipes pluridisciplinaires",
    "Planification de projets {} avec des délais serrés",
    "Suivi de l'avancement de {} projets simultanés",
    "Supervision des opérations de {} dans des environnements complexes",
    "Gestion des opérations quotidiennes de {} départements",
    "Optimisation des opérations {} pour réduire les coûts",
    "Mise en œuvre de stratégies {} pour améliorer la productivité",
    "Développement de plans stratégiques {} pour une croissance durable",
    "Alignement des objectifs {} avec la vision de l’entreprise",
    "Négociation de contrats {} avec des partenaires stratégiques",
    "Gestion de relations avec {} parties prenantes",
    "Animation de réunions {} pour aligner les équipes",
    "Communication de résultats {} à des comités exécutifs",
    "Gestion des risques {} sur des projets critiques",
    "Identification de {} risques opérationnels majeurs",
    "Mise en place de plans de mitigation pour {} risques",
    "Gestion de crises {} impactant les opérations",
    "Conduite de transformations {} dans des organisations complexes",
    "Accompagnement au changement pour {} employés",
    "Digitalisation des processus {} pour moderniser les opérations",
    "Implémentation d’outils numériques {} pour la gestion d’équipe",
    "Utilisation d’ERP {} pour optimiser la gestion",
    "Gestion de projets agiles {} avec la méthodologie Scrum",
    "Application de méthodologies {} comme PRINCE2 ou PMI",
    "Coordination de {} sprints dans des projets agiles",
    "Gestion de portefeuilles de {} projets stratégiques",
    "Priorisation de {} initiatives pour maximiser l’impact",
    "Supervision de programmes {} à grande échelle",
    "Gestion de budgets de {}M€ pour des programmes complexes",
    "Évaluation de l’impact de {} initiatives sur la performance",
    "Mise en place de KPI pour {} projets ou opérations",
    "Création de tableaux de bord pour {} métriques clés",
    "Reporting mensuel sur {} indicateurs de performance",
    "Gestion de la qualité {} selon les normes ISO",
    "Contrôle qualité de {} livrables critiques",
    "Gestion des sous-traitants {} pour des projets externalisés",
    "Négociation avec {} fournisseurs pour optimiser les coûts",
    "Évaluation de {} fournisseurs pour garantir la qualité",
    "Gestion des relations avec {} clients stratégiques",
    "Fidélisation de {} comptes clés",
    "Gestion interculturelle de {} équipes internationales",
    "Coordination de {} équipes à distance",
    "Gestion de {} équipes virtuelles via des outils collaboratifs",
    "Animation de {} workshops pour aligner les objectifs",
    "Facilitation de {} sessions de brainstorming stratégiques",
    "Mentorat de {} managers pour développer leurs compétences",
    "Coaching de {} leaders pour renforcer leur impact",
    "Gestion des conflits au sein de {} équipes",
    "Résolution de {} conflits critiques entre parties prenantes",
    "Mise en place de plans de continuité pour {} opérations",
    "Gestion de {} crises opérationnelles majeures",
    "Évaluation des performances de {} processus clés",
    "Optimisation de {} flux de travail pour réduire les délais",
    "Mise en œuvre de pratiques lean pour {} opérations",
    "Application de Six Sigma pour {} projets d’amélioration",
    "Gestion de {} initiatives d’innovation",
    "Pilotage de {} projets de transformation digitale",
    "Gestion de {} projets R&D stratégiques",
    "Coordination de {} projets à impact social",
    "Gestion de {} projets ESG (Environnement, Social, Gouvernance)",
    "Mise en place de pratiques durables pour {} opérations",
    "Gestion de {} projets de responsabilité sociétale (RSE)",
    "Supervision de {} audits internes pour la conformité",
    "Mise en conformité avec {} réglementations sectorielles",
    "Gestion de {} audits RGPD pour les données sensibles",
    "Supervision de {} initiatives de cybersécurité",
    "Gestion de {} bases de données opérationnelles",
    "Analyse de {} ensembles de données pour la prise de décision",
    "Utilisation de l’IA pour optimiser {} processus de gestion",
    "Gestion de {} projets basés sur l’intelligence artificielle",
    "Supervision de {} initiatives Big Data",
    "Mise en place de {} solutions d’automatisation",
    "Gestion de {} intégrations d’outils numériques",
    "Coordination de {} projets multiculturels",
    "Gestion de {} projets à faible budget",
    "Optimisation des ressources pour {} projets contraints",
    "Gestion de {} partenariats stratégiques",
    "Négociation de {} accords de collaboration",
    "Gestion de {} équipes bénévoles dans des projets associatifs",
    "Supervision de {} projets humanitaires",
    "Gestion de {} projets éducatifs ou culturels",
    "Coordination de {} événements d’entreprise",
    "Gestion de {} campagnes de changement organisationnel",
    "Mise en place de {} programmes de formation pour managers",
    "Évaluation de {} programmes de développement des talents",
    "Gestion de {} initiatives de bien-être au travail",
    "Supervision de {} projets de diversité et inclusion",
    "Gestion de {} projets de communication interne",
    "Animation de {} sessions de feedback pour les équipes",
    "Mise en place de {} stratégies de motivation d’équipe"
        # Communication / Marketing
        "Création et déploiement de stratégies de communication {}",
        "Organisation d'événements {} avec {} participants",
        "Rédaction de contenus pour {}",
        "Gestion des relations avec {}",
        "Élaboration de campagnes de marketing {}",
        "Création et déploiement de stratégies de communication {} pour des audiences variées",
    "Élaboration de plans de communication {} pour renforcer la marque",
    "Mise en œuvre de campagnes de communication {} sur plusieurs canaux",
    "Organisation d'événements {} avec {} participants",
    "Coordination d'événements virtuels {} pour {} utilisateurs en ligne",
    "Planification de salons professionnels {} attirant {} visiteurs",
    "Gestion de festivals culturels {} avec {} spectateurs",
    "Rédaction de contenus pour {} plateformes digitales",
    "Création de contenus SEO {} pour optimiser le référencement",
    "Production de contenus publicitaires {} pour des campagnes ciblées",
    "Rédaction de communiqués de presse {} pour des médias nationaux",
    "Élaboration de storytelling {} pour engager les audiences",
    "Gestion des relations avec {} médias pour maximiser la couverture",
    "Négociation avec {} influenceurs pour des partenariats stratégiques",
    "Coordination des relations avec {} parties prenantes externes",
    "Maintien des relations avec {} clients pour renforcer la fidélité",
    "Élaboration de campagnes de marketing {} pour des lancements de produits",
    "Conception de campagnes digitales {} sur {} réseaux sociaux",
    "Mise en place de campagnes SEA {} pour augmenter le trafic",
    "Développement de campagnes de marketing d’influence {} avec {} créateurs",
    "Création de campagnes de marketing par e-mail {} pour {} abonnés",
    "Gestion de campagnes programmatiques {} pour optimiser les dépenses",
    "Analyse des performances de {} campagnes marketing",
    "Suivi des KPI pour {} initiatives marketing",
    "Création de tableaux de bord marketing pour {} métriques",
    "Optimisation des conversions pour {} campagnes digitales",
    "Mise en œuvre de tests A/B pour {} stratégies marketing",
    "Déploiement de stratégies omnicanales {} pour une expérience unifiée",
    "Coordination de stratégies multicanales {} pour maximiser la portée",
    "Développement de stratégies de contenu {} pour des audiences spécifiques",
    "Création de contenus vidéo {} pour des plateformes comme YouTube",
    "Production de podcasts {} pour engager des communautés",
    "Gestion de live streaming {} pour des événements en direct",
    "Conception de visuels {} pour des campagnes publicitaires",
    "Création d’infographies {} pour vulgariser des concepts",
    "Mise en forme de présentations {} pour des pitchs stratégiques",
    "Gestion des réseaux sociaux {} pour {} abonnés",
    "Animation de communautés en ligne {} pour renforcer l’engagement",
    "Création de calendriers éditoriaux {} pour les réseaux sociaux",
    "Gestion de publicités payantes {} sur les réseaux sociaux",
    "Analyse de l’engagement sur {} publications sociales",
    "Développement de stratégies SEO {} pour améliorer le classement",
    "Mise en œuvre de stratégies SMO {} pour optimiser la présence sociale",
    "Gestion de projets marketing {} avec des équipes pluridisciplinaires",
    "Coordination de lancements de produits {} sur {} marchés",
    "Planification de campagnes de pré-lancement {} pour créer l’attente",
    "Suivi des campagnes post-lancement {} pour maximiser les ventes",
    "Création de stratégies de marque {} pour renforcer l’identité",
    "Développement d’identités visuelles {} pour des marques",
    "Positionnement de marque {} pour des segments spécifiques",
    "Gestion de la réputation en ligne pour {} marques",
    "Réponse aux avis clients {} pour améliorer l’e-réputation",
    "Mise en place de stratégies de fidélisation pour {} clients",
    "Conception de programmes de fidélité {} pour {} utilisateurs",
    "Gestion de CRM {} pour optimiser les relations clients",
    "Segmentation de {} bases de clients pour des campagnes ciblées",
    "Automatisation de {} processus marketing via des outils CRM",
    "Analyse des données marketing {} pour orienter les décisions",
    "Utilisation de Google Analytics pour {} campagnes digitales",
    "Création de rapports marketing {} pour les parties prenantes",
    "Mise en œuvre de stratégies data-driven pour {} initiatives",
    "Développement de stratégies de marketing prédictif {}",
    "Utilisation de l’IA pour optimiser {} campagnes marketing",
    "Gestion de {} projets de marketing automation",
    "Coordination de {} campagnes de marketing viral",
    "Mise en place de stratégies de gamification {} pour l’engagement",
    "Développement de campagnes de marketing expérientiel {}",
    "Création de campagnes de marketing sensoriel {}",
    "Gestion de campagnes de marketing direct {}",
    "Mise en œuvre de campagnes de street marketing {}",
    "Coordination de campagnes de marketing éthique {}",
    "Développement de campagnes de green marketing {}",
    "Mise en place de campagnes inclusives {} pour la diversité",
    "Gestion de campagnes de marketing culturel {}",
    "Coordination de campagnes de marketing sportif {}",
    "Mise en œuvre de campagnes de marketing de luxe {}",
    "Gestion de {} partenariats de marque",
    "Négociation de {} contrats de sponsoring",
    "Mise en place de stratégies de mécénat {}",
    "Coordination de campagnes de crowdfunding {}",
    "Gestion de campagnes de marketing B2B {}",
    "Développement de campagnes de marketing B2C {}",
    "Mise en œuvre de stratégies de marketing international {}",
    "Localisation de contenus marketing pour {} marchés",
    "Gestion de campagnes de marketing géolocalisé {}",
    "Coordination de campagnes de marketing mobile {}",
    "Mise en place de stratégies pour le métavers {}",
    "Développement de campagnes en réalité augmentée {}",
    "Création de campagnes en réalité virtuelle {}",
    "Gestion de {} projets de communication de crise",
    "Mise en place de plans de continuité pour {} campagnes",
    "Coordination de {} initiatives de communication interne",
    "Gestion de {} projets de communication corporate",
    "Mise en œuvre de stratégies de communication interculturelle {}",
    "Traduction de contenus marketing pour {} langues",
    "Mise en place de stratégies d’accessibilité numérique {}",
    "Gestion de {} projets de communication RSE",
    "Coordination de {} campagnes de sensibilisation sociale",
    "Mise en œuvre de stratégies de communication durable {}",
    "Gestion de {} audits de communication",
    "Analyse de l’impact de {} campagnes sur l’audience",
    "Mise en place de veilles stratégiques pour {} tendances marketing",
    "Formation d’équipes à {} outils de marketing digital",
    "Mentorat de {} professionnels en communication",
    "Gestion de {} communautés de marque en ligne",
    "Coordination de {} projets de communication participative",
        # Commercial / Vente
        "Prospection et développement d'un portefeuille clients {}",
        "Négociation de contrats avec {}",
        "Augmentation du chiffre d'affaires de {}%",
        "Réalisation d'études de marché pour {}",
        "Gestion de la relation client pour {}",
        # Administration / RH
        "Gestion administrative de {}",
        "Recrutement et intégration de {} nouvelles personnes",
        "Traitement de dossiers {}",
        "Mise en place de formations pour {}",
        "Élaboration et suivi du plan de développement {}",
        # Technique / Production
        "Conception et développement de {}",
        "Maintenance et optimisation de {}",
        "Gestion de la production de {}",
        "Résolution de problématiques techniques liées à {}",
        "Mise en œuvre de solutions pour {}"
    ]

    for i in range(experience_count):
        entreprise = random.choice(entreprises)
        poste = random.choice(postes)
        annee_fin = 2023 - i
        annee_debut = annee_fin - random.randint(1, 4)
        # Formats variés pour les durées
        duree_formats = [
            f"{annee_debut}-{annee_fin}",
            f"{annee_debut} - {annee_fin}",
            f"{annee_debut} à {annee_fin}",
            f"De {annee_debut} à {annee_fin}",
            f"{annee_debut}-Présent" if i == 0 and random.choice([True, False]) else f"{annee_debut}-{annee_fin}"
        ]
        duree = random.choice(duree_formats)
        ville_exp = random.choice(villes)

        # Sélection et personnalisation de 2-4 descriptifs
        # Sélection et personnalisation de 2-4 descriptifs
        nb_descriptifs = random.randint(2, 4)
        description = ""
        for _ in range(nb_descriptifs):
            # Sélectionner un descriptif aléatoire
            descriptif_base = random.choice(descriptifs_generiques)

            try:
                # Essayer de personnaliser le descriptif
                descriptif = personnaliser_descriptif(descriptif_base)
                description += f"• {descriptif}\n"
            except Exception as e:
                # En cas d'erreur, utiliser un descriptif de secours simple
                print(f"Erreur avec le descriptif: {descriptif_base}, erreur: {e}")
                description += f"• Participation à des projets d'amélioration continue\n"

        # Varier le format de présentation des expériences
        format_type = random.randint(1, 5)
        if format_type == 1:
            exp_str = f"- {poste} chez {entreprise}, {duree}\n  {ville_exp}\n{description}\n"
        elif format_type == 2:
            exp_str = f"{duree} - {poste}\n{entreprise}, {ville_exp}\n{description}\n"
        elif format_type == 3:
            exp_str = f"{poste}\n{entreprise} - {ville_exp} - {duree}\n{description}\n"
        elif format_type == 4:
            exp_str = f"{entreprise} | {poste}\n{ville_exp} | {duree}\n{description}\n"
        else:
            exp_str = f"{poste} - {entreprise}\n{duree} | {ville_exp}\n{description}\n"

        experience_text += exp_str

        # Ajouter les entités
        start_poste = experience_text.find(poste)
        if start_poste != -1:
            experience_entities.append((start_poste, start_poste + len(poste), "POSTE"))

        start_entreprise = experience_text.find(entreprise)
        if start_entreprise != -1:
            experience_entities.append((start_entreprise, start_entreprise + len(entreprise), "ENTREPRISE"))

        start_duree = experience_text.find(duree)
        if start_duree != -1:
            experience_entities.append((start_duree, start_duree + len(duree), "DUREE"))

    experience_text += "\n"

    # Compétences avec catégories adaptées à tous domaines
    competences_categories_generales = {
        # Compétences techniques par domaine
        "Informatique & Numérique": [
    "Développement logiciel",
    "Développement web (Frontend)",
    "Développement web (Backend)",
    "Développement full-stack",
    "Développement mobile (iOS)",
    "Développement mobile (Android)",
    "Développement multiplateforme (Flutter, React Native)",
    "Développement de jeux vidéo",
    "Développement embarqué",
    "Développement de systèmes temps réel",
    "Gestion de bases de données relationnelles (SQL)",
    "Gestion de bases de données NoSQL",
    "Administration système (Linux)",
    "Administration système (Windows)",
    "Administration de serveurs",
    "Virtualisation (VMware, Hyper-V)",
    "Conteneurisation (Docker, Kubernetes)",
    "Cybersécurité (analyse des vulnérabilités)",
    "Cybersécurité (pentesting)",
    "Cybersécurité (gestion des incidents)",
    "Cryptographie",
    "Sécurité des réseaux",
    "UX/UI Design",
    "Design d’interfaces (UI)",
    "Recherche utilisateur (UX Research)",
    "Prototypage (Figma, Adobe XD)",
    "Intelligence artificielle (IA générale)",
    "Machine Learning",
    "Deep Learning",
    "Traitement du langage naturel (NLP)",
    "Vision par ordinateur",
    "Systèmes experts",
    "Cloud computing (AWS)",
    "Cloud computing (Azure)",
    "Cloud computing (Google Cloud)",
    "Cloud computing (architecture serverless)",
    "Analyse de données",
    "Data Science",
    "Data Engineering",
    "Big Data (Hadoop, Spark)",
    "Business Intelligence",
    "Visualisation de données (Tableau, Power BI)",
    "Réseaux informatiques (configuration)",
    "Réseaux informatiques (administration)",
    "Réseaux 5G",
    "Internet des objets (IoT)",
    "Blockchain (développement de smart contracts)",
    "Blockchain (infrastructure)",
    "DevOps (CI/CD)",
    "DevOps (automatisation)",
    "Site Reliability Engineering (SRE)",
    "Test et assurance qualité (QA)",
    "Tests automatisés",
    "Tests de performance",
    "Gestion de projets IT (Agile, Scrum)",
    "Gestion de projets IT (PMP, PRINCE2)",
    "Architecture logicielle",
    "Architecture d’entreprise",
    "Microservices",
    "SOA (Service-Oriented Architecture)",
    "Automatisation des processus (RPA)",
    "Administration de ERP (SAP, Oracle)",
    "Administration de CRM (Salesforce, HubSpot)",
    "Infographie et design 3D",
    "Animation 2D/3D",
    "Réalité virtuelle (VR)",
    "Réalité augmentée (AR)",
    "Métavers (développement)",
    "Edge Computing",
    "Calcul haute performance (HPC)",
    "Programmation fonctionnelle",
    "Programmation orientée objet",
    "Programmation bas niveau",
    "Scripting (Python, Bash)",
    "Développement d’API",
    "Gestion de contenu (CMS comme WordPress)",
    "SEO technique",
    "Marketing numérique (analyse web)",
    "Gestion de l’infrastructure IT",
    "Audit informatique",
    "Gouvernance des données",
    "Conformité RGPD",
    "Forensic informatique",
    "Reverse engineering",
    "Bioinformatique",
    "Informatique quantique",
    "Simulation numérique",
    "Systèmes d’information géographique (SIG)",
    "Gestion de la continuité des activités IT",
    "Support technique (niveau 1, 2, 3)",
    "Formation et sensibilisation IT",
    "Veille technologique",
    "Éthique en IA",
    "Accessibilité numérique",
    "Optimisation des performances",
    "Gestion des identités et des accès (IAM)",
    "Monitoring et observabilité",
    "Développement de chatbots",
    "Systèmes de recommandation",
    "Analyse prédictive",
    "Modélisation 3D",
    "Développement de solutions SaaS",
    "Développement de solutions PaaS",
    "Développement de solutions IaaS",
    "Intégration de systèmes",
    "Gestion de la transformation numérique",
    "Analyse de la performance réseau",
    "Développement de middleware",
    "Gestion des API (API Gateway)",
    "Développement low-code/no-code",
    "Gestion de la qualité des données",
    "Développement de solutions de paiement numérique",
    "Administration de solutions de collaboration (Microsoft Teams, Slack)",
    "Développement de solutions e-commerce",
    "Analyse de la cybersécurité des IoT",
    "Développement de solutions de santé numérique",
    "Automatisation du cloud"
],
        "Marketing & Communication": [
    "Marketing digital",
    "Marketing de contenu",
    "Marketing d’influence",
    "Marketing par e-mail",
    "Marketing automation",
    "Relations presse",
    "Relations publiques",
    "Gestion des réseaux sociaux",
    "Stratégie de réseaux sociaux",
    "Community management",
    "Rédaction web",
    "Rédaction publicitaire (copywriting)",
    "Rédaction de contenu SEO",
    "Rédaction technique",
    "Stratégie de marque",
    "Branding",
    "Positionnement de marque",
    "Identité visuelle",
    "Événementiel",
    "Organisation de salons professionnels",
    "Gestion d’événements virtuels",
    "SEO (Search Engine Optimization)",
    "SEA (Search Engine Advertising)",
    "SMO (Social Media Optimization)",
    "SEM (Search Engine Marketing)",
    "Analyse de données marketing",
    "Web analytics (Google Analytics, Adobe Analytics)",
    "CRM (Customer Relationship Management)",
    "Fidélisation client",
    "Expérience client (CX)",
    "Études de marché",
    "Analyse de la concurrence",
    "Comportement du consommateur",
    "Segmentation de marché",
    "Publicité traditionnelle (TV, radio, affichage)",
    "Publicité programmatique",
    "Publicité native",
    "Marketing direct",
    "Street marketing",
    "Guerilla marketing",
    "Marketing expérientiel",
    "Marketing sensoriel",
    "Stratégie omnicanale",
    "Stratégie multicanale",
    "Communication corporate",
    "Communication interne",
    "Communication de crise",
    "Gestion de réputation",
    "Storytelling",
    "Production audiovisuelle (vidéo marketing)",
    "Motion design",
    "Photographie publicitaire",
    "Design graphique (publicité)",
    "Infographie",
    "Marketing B2B",
    "Marketing B2C",
    "Marketing international",
    "Marketing local",
    "Marketing éthique",
    "Marketing durable",
    "Green marketing",
    "Marketing inclusif",
    "Marketing de luxe",
    "Marketing sportif",
    "Marketing culturel",
    "Marketing politique",
    "Sponsoring",
    "Partenariats de marque",
    "Gestion de campagnes publicitaires",
    "Planification média",
    "Achat d’espace publicitaire",
    "Négociation avec les médias",
    "Stratégie cross-média",
    "Marketing viral",
    "Gamification",
    "Marketing mobile",
    "Marketing géolocalisé",
    "Marketing de proximité (NFC, QR codes)",
    "Affiliation marketing",
    "E-commerce marketing",
    "Optimisation des conversions (CRO)",
    "Tests A/B",
    "Personnalisation marketing",
    "Data-driven marketing",
    "Gestion de projets marketing",
    "Budget marketing",
    "ROI marketing",
    "KPI marketing",
    "Veille stratégique",
    "Tendances marketing",
    "Communication interculturelle",
    "Traduction marketing",
    "Localisation de contenu",
    "Accessibilité numérique (marketing)",
    "Marketing conversationnel (chatbots)",
    "Marketing vocal (assistants vocaux)",
    "Marketing pour le métavers",
    "Marketing en réalité augmentée (AR)",
    "Marketing en réalité virtuelle (VR)",
    "Gestion des avis clients",
    "E-réputation",
    "Influence digitale",
    "Création de podcasts",
    "Stratégie de contenu vidéo",
    "Live streaming (marketing)",
    "Marketing événementiel digital",
    "Marketing pour les ONG",
    "Crowdfunding marketing",
    "Marketing de cause",
    "Advocacy marketing",
    "Marketing de réseau",
    "Formation en communication",
    "Sensibilisation des parties prenantes",
    "Gestion des médias sociaux payants",
    "Analyse de l’engagement",
    "Stratégie de lancement de produit",
    "Marketing de pré-lancement",
    "Marketing post-lancement",
    "Gestion de la communauté de marque",
    "Création de campagnes virales",
    "Marketing de micro-influenceurs",
    "Marketing de niche",
    "Marketing pour startups",
    "Marketing agile",
    "Communication visuelle",
    "Stratégie de contenu multilingue",
    "Marketing prédictif",
    "Analyse prédictive marketing",
    "Marketing basé sur l’IA",
    "Personnalisation en temps réel",
    "Gestion des données clients (CDP)",
    "Conformité RGPD (marketing)"
],
        "Finance & Comptabilité": [
    "Analyse financière",
    "Comptabilité générale",
    "Comptabilité analytique",
    "Contrôle de gestion",
    "Gestion de trésorerie",
    "Fiscalité",
    "Audit interne",
    "Audit externe",
    "Reporting financier",
    "Consolidation des comptes",
    "Comptabilité publique",
    "Comptabilité internationale (IFRS, GAAP)",
    "Gestion budgétaire",
    "Planification financière",
    "Prévisions financières",
    "Évaluation d’entreprise",
    "Modélisation financière",
    "Analyse des ratios financiers",
    "Gestion des risques financiers",
    "Risk management",
    "Gestion de portefeuille",
    "Investissements financiers",
    "Marchés financiers",
    "Produits dérivés",
    "Trading financier",
    "Finance d’entreprise",
    "Finance de marché",
    "Finance comportementale",
    "Finance quantitative",
    "Finance durable",
    "Finance verte",
    "Investissement ESG",
    "Gestion des actifs",
    "Private equity",
    "Venture capital",
    "Fusions et acquisitions (M&A)",
    "Due diligence",
    "Restructuration financière",
    "Financement de projets",
    "Financement participatif (crowdfunding)",
    "Leasing et financement d’équipements",
    "Gestion de la dette",
    "Trésorerie internationale",
    "Gestion des flux de trésorerie",
    "Optimisation de la trésorerie",
    "Gestion des paiements",
    "Comptabilité fournisseurs",
    "Comptabilité clients",
    "Facturation",
    "Recouvrement de créances",
    "Fiscalité des entreprises",
    "Fiscalité internationale",
    "Fiscalité des particuliers",
    "Optimisation fiscale",
    "Contrôle fiscal",
    "Déclarations fiscales",
    "TVA et taxes indirectes",
    "Audit comptable",
    "Audit financier",
    "Audit de conformité",
    "Audit de performance",
    "Audit des systèmes d’information",
    "Contrôle interne",
    "Gouvernance d’entreprise",
    "Conformité réglementaire",
    "Lutte contre le blanchiment d’argent (AML)",
    "Conformité KYC (Know Your Customer)",
    "Gestion des normes SOX",
    "Reporting ESG",
    "Reporting extra-financier",
    "Analyse des écarts budgétaires",
    "Costing (calcul des coûts)",
    "Pricing (stratégie de tarification)",
    "Analyse de rentabilité",
    "Gestion des immobilisations",
    "Amortissements et provisions",
    "Clôture comptable",
    "Révision comptable",
    "Comptabilité de gestion",
    "Comptabilité environnementale",
    "Comptabilité sociale",
    "Gestion des subventions",
    "Comptabilité des associations",
    "Comptabilité des PME",
    "Comptabilité des grands groupes",
    "Gestion des ERP financiers (SAP, Oracle)",
    "Automatisation comptable",
    "Digitalisation des processus financiers",
    "Blockchain en finance",
    "Cryptomonnaies et actifs numériques",
    "Fintech",
    "Paiements numériques",
    "Analyse prédictive financière",
    "Data analytics en finance",
    "Business intelligence financière",
    "Tableaux de bord financiers",
    "Gestion des KPI financiers",
    "Planification stratégique",
    "Conseil financier",
    "Accompagnement à la levée de fonds",
    "Évaluation des risques fiscaux",
    "Gestion des litiges fiscaux",
    "Négociation avec les autorités fiscales",
    "Gestion des devises (forex)",
    "Hedging (couverture des risques)",
    "Finance islamique",
    "Microfinance",
    "Gestion des assurances",
    "Analyse de crédit",
    "Scoring de crédit",
    "Gestion des prêts",
    "Comptabilité des projets",
    "Contrôle des coûts de projets",
    "Gestion des flux intercompagnies",
    "Transfer pricing",
    "Comptabilité des holdings",
    "Gestion des dividendes",
    "Communication financière",
    "Relations avec les investisseurs",
    "Veille réglementaire",
    "Formation en finance",
    "Éthique financière",
    "Gestion des données financières",
    "Conformité RGPD (finance)",
    "Cybersécurité financière",
    "Analyse des performances financières",
    "Optimisation des processus financiers",
    "Gestion des audits externes",
    "Plan de continuité financière",
    "Gestion de la transformation digitale financière"
],
        "Ressources Humaines": [
    "Recrutement",
    "Sourcing de candidats",
    "Chasse de têtes",
    "Entretiens d’embauche",
    "Évaluation des compétences",
    "Onboarding",
    "Offboarding",
    "Gestion des talents",
    "Plan de développement des talents",
    "Succession planning",
    "Formation",
    "Conception de programmes de formation",
    "Formation en ligne (e-learning)",
    "Coaching professionnel",
    "Mentoring",
    "Administration du personnel",
    "Gestion des contrats de travail",
    "Gestion des dossiers salariés",
    "SIRH (Systèmes d’Information des Ressources Humaines)",
    "Implémentation de SIRH (SAP, Workday, Oracle)",
    "Maintenance de SIRH",
    "Relations sociales",
    "Négociation avec les syndicats",
    "Gestion des conflits sociaux",
    "Dialogue social",
    "Paie",
    "Gestion de la paie",
    "Calcul des cotisations sociales",
    "Déclarations sociales",
    "Conformité paie",
    "Gestion des avantages sociaux",
    "Plans de retraite",
    "Mutuelles et prévoyance",
    "Gestion des absences",
    "Gestion des congés",
    "Gestion du temps de travail",
    "Planification des effectifs",
    "Gestion des talents internationaux",
    "Mobilité internationale",
    "Expatriation et rapatriation",
    "Diversité et inclusion",
    "Égalité professionnelle",
    "Gestion des biais inconscients",
    "Accessibilité au travail",
    "Bien-être au travail",
    "Prévention des risques psychosociaux",
    "Qualité de vie au travail (QVT)",
    "Engagement des employés",
    "Culture d’entreprise",
    "Marque employeur",
    "Communication interne",
    "Gestion du changement",
    "Transformation organisationnelle",
    "Réorganisation d’entreprise",
    "Outplacement",
    "Gestion des licenciements",
    "Médiation en entreprise",
    "Résolution de conflits",
    "Évaluation de la performance",
    "Feedback 360°",
    "KPI RH",
    "Analyse des données RH",
    "People analytics",
    "Tableaux de bord RH",
    "Prévisions des besoins en RH",
    "Stratégie RH",
    "Alignement RH avec les objectifs business",
    "Gestion des compétences",
    "Référentiels de compétences",
    "Upskilling",
    "Reskilling",
    "Développement du leadership",
    "Gestion des hauts potentiels",
    "Programmes de fidélisation",
    "Rémunération et avantages",
    "Benchmarking des salaires",
    "Stratégie de rémunération",
    "Équité salariale",
    "Gestion des primes et bonus",
    "Conformité RGPD (RH)",
    "Protection des données RH",
    "Cybersécurité RH",
    "Audit RH",
    "Contrôle interne RH",
    "Veille réglementaire RH",
    "Conformité légale RH",
    "Droit du travail",
    "Gestion des contentieux RH",
    "Négociation des accords d’entreprise",
    "Gestion des freelances",
    "Gestion des intérimaires",
    "Recrutement inclusif",
    "Gestion des stagiaires",
    "Programmes de jeunes diplômés",
    "Partenariats avec les écoles",
    "Gestion des alumni",
    "RSE (Responsabilité Sociétale des Entreprises) en RH",
    "RH durable",
    "Gestion des crises RH",
    "Plan de continuité RH",
    "Télétravail et travail hybride",
    "Flexibilité du travail",
    "Automatisation des processus RH",
    "Digitalisation RH",
    "IA en RH",
    "Chatbots RH",
    "Recrutement prédictif",
    "Analyse prédictive RH",
    "Gamification RH",
    "Expérience collaborateur",
    "Parcours collaborateur",
    "Gestion des talents digitaux",
    "Formation aux soft skills",
    "Formation aux hard skills",
    "Éthique RH",
    "Sensibilisation RH",
    "Gestion multigénérationnelle",
    "Gestion interculturelle",
    "Communication RH externe",
    "Storytelling RH",
    "Gestion des retours d’expérience",
    "Enquêtes de satisfaction RH",
    "Gestion des ambassadeurs RH",
    "RH agile",
    "Lean RH",
    "Gestion des projets RH",
    "Optimisation des processus RH"
],
        "Commercial & Vente": [
    "Prospection",
    "Prospection téléphonique",
    "Prospection terrain",
    "Prospection digitale",
    "Génération de leads",
    "Qualification de leads",
    "Négociation",
    "Négociation B2B",
    "Négociation B2C",
    "Négociation internationale",
    "Closing de ventes",
    "Gestion de portefeuille clients",
    "Fidélisation client",
    "Upselling",
    "Cross-selling",
    "Stratégie commerciale",
    "Planification commerciale",
    "Développement commercial",
    "Expansion de marché",
    "Pénétration de marché",
    "E-commerce",
    "Gestion de plateformes e-commerce",
    "Optimisation des ventes en ligne",
    "CRM (Customer Relationship Management)",
    "Administration de CRM (Salesforce, HubSpot)",
    "Automatisation CRM",
    "Analyse des données CRM",
    "Segmentation client",
    "Gestion des comptes clés (Key Account Management)",
    "Vente consultative",
    "Vente solution",
    "Vente complexe",
    "Vente transactionnelle",
    "Vente directe",
    "Vente indirecte (via partenaires)",
    "Gestion de canaux de distribution",
    "Partenariats commerciaux",
    "Franchise commerciale",
    "Vente au détail (retail)",
    "Merchandising",
    "Visual merchandising",
    "Pricing (stratégie de tarification)",
    "Négociation de prix",
    "Gestion des remises",
    "Analyse de la concurrence",
    "Veille concurrentielle",
    "Positionnement commercial",
    "Études de marché",
    "Analyse des besoins clients",
    "Customer Success",
    "Expérience client (CX)",
    "Service après-vente",
    "Gestion des réclamations clients",
    "Gestion des avis clients",
    "E-réputation commerciale",
    "Marketing commercial",
    "Promotion des ventes",
    "Campagnes de vente",
    "Lancement de produits",
    "Stratégie de pré-lancement",
    "Stratégie post-lancement",
    "Vente événementielle",
    "Salons professionnels",
    "Démonstrations produit",
    "Webinaires de vente",
    "Vente sociale (social selling)",
    "Vente via réseaux sociaux",
    "Publicité ciblée",
    "SEO/SEA pour la vente",
    "Emailing commercial",
    "Cold emailing",
    "Marketing direct",
    "Vente multicanale",
    "Vente omnicanale",
    "Vente internationale",
    "Exportation",
    "Localisation des ventes",
    "Gestion des devises dans les ventes",
    "Vente éthique",
    "Vente durable",
    "Vente verte",
    "Vente inclusive",
    "Vente de luxe",
    "Vente technique",
    "Vente de services",
    "Vente de logiciels (SaaS)",
    "Vente de matériel",
    "Vente par abonnement",
    "Vente par affiliation",
    "Crowdfunding commercial",
    "Gamification des ventes",
    "Vente mobile",
    "Vente géolocalisée",
    "Vente en réalité augmentée (AR)",
    "Vente en réalité virtuelle (VR)",
    "Vente dans le métavers",
    "Analyse des performances commerciales",
    "KPI commerciaux",
    "Tableaux de bord commerciaux",
    "Prévisions de ventes",
    "Data-driven selling",
    "Analyse prédictive des ventes",
    "IA dans la vente",
    "Automatisation des processus de vente",
    "Digitalisation des ventes",
    "Gestion des objections",
    "Storytelling commercial",
    "Pitch commercial",
    "Communication persuasive",
    "Négociation de contrats",
    "Rédaction de propositions commerciales",
    "Gestion des appels d’offres",
    "Vente publique",
    "Vente aux enchères",
    "Gestion des équipes commerciales",
    "Coaching commercial",
    "Formation des commerciaux",
    "Motivation des équipes de vente",
    "Recrutement de commerciaux",
    "Gestion des commissions",
    "Conformité réglementaire (vente)",
    "Conformité RGPD (vente)",
    "Cybersécurité dans les ventes",
    "Gestion des données clients",
    "Veille technologique commerciale",
    "Stratégie de vente agile",
    "Lean selling",
    "Gestion de projets commerciaux",
    "Optimisation des processus de vente",
    "Gestion des crises commerciales"
],
        "Juridique": [
    "Droit des affaires",
    "Droit commercial",
    "Droit des contrats",
    "Droit social",
    "Droit du travail",
    "Propriété intellectuelle",
    "Droit des marques",
    "Droit des brevets",
    "Droit d’auteur",
    "Contrats commerciaux",
    "Négociation de contrats",
    "Rédaction de contrats",
    "Droit fiscal",
    "Fiscalité des entreprises",
    "Fiscalité internationale",
    "Conformité",
    "Conformité réglementaire",
    "Droit des sociétés",
    "Constitution de sociétés",
    "Gouvernance d’entreprise",
    "Fusions et acquisitions (M&A)",
    "Due diligence juridique",
    "Droit pénal des affaires",
    "Droit de la concurrence",
    "Droit antitrust",
    "Droit de la consommation",
    "Droit immobilier",
    "Droit de la construction",
    "Droit des baux",
    "Droit de l’environnement",
    "Droit de l’énergie",
    "Droit maritime",
    "Droit aérien",
    "Droit des transports",
    "Droit bancaire",
    "Droit financier",
    "Droit des marchés de capitaux",
    "Droit des assurances",
    "Droit de la santé",
    "Droit pharmaceutique",
    "Droit du sport",
    "Droit de la famille",
    "Droit des successions",
    "Droit pénal",
    "Droit pénal international",
    "Droit civil",
    "Droit des obligations",
    "Droit de la responsabilité",
    "Droit administratif",
    "Droit public",
    "Droit constitutionnel",
    "Droit européen",
    "Droit international public",
    "Droit international privé",
    "Droit humanitaire",
    "Droit des réfugiés",
    "Droit de l’arbitrage",
    "Médiation",
    "Règlement alternatif des litiges (ADR)",
    "Contentieux commercial",
    "Contentieux civil",
    "Contentieux administratif",
    "Contentieux pénal",
    "Contentieux fiscal",
    "Droit de la propriété industrielle",
    "Droit des nouvelles technologies",
    "Droit du numérique",
    "Droit de la cybersécurité",
    "Protection des données personnelles",
    "Conformité RGPD",
    "Droit de l’internet",
    "Droit des médias",
    "Droit de la presse",
    "Droit de la publicité",
    "Droit du e-commerce",
    "Droit de la blockchain",
    "Droit des cryptomonnaies",
    "Droit des fintech",
    "Droit de l’intelligence artificielle",
    "Éthique juridique",
    "Droit du travail international",
    "Droit des relations collectives",
    "Négociation d’accords d’entreprise",
    "Droit de la sécurité sociale",
    "Droit de la fonction publique",
    "Droit des organisations internationales",
    "Droit du commerce international",
    "Droit douanier",
    "Droit des investissements étrangers",
    "Droit de l’urbanisme",
    "Droit foncier",
    "Droit rural",
    "Droit de la chasse et de la pêche",
    "Droit du tourisme",
    "Droit des jeux et paris",
    "Droit de la mode",
    "Droit du luxe",
    "Droit des startups",
    "Droit des associations",
    "Droit des fondations",
    "Droit des ONG",
    "Droit fiscal des particuliers",
    "Optimisation fiscale",
    "Droit patrimonial",
    "Planification successorale",
    "Droit des trusts",
    "Droit des restructurations",
    "Droit de la faillite",
    "Droit des liquidations",
    "Droit des sûretés",
    "Audit juridique",
    "Veille juridique",
    "Analyse des risques juridiques",
    "Conseil juridique",
    "Formation juridique",
    "Communication juridique",
    "Rédaction juridique",
    "Traduction juridique",
    "Localisation juridique",
    "Droit de la compliance",
    "Lutte contre le blanchiment d’argent (AML)",
    "Conformité KYC (Know Your Customer)",
    "Gestion des litiges",
    "Stratégie contentieuse",
    "Droit de l’exécution des jugements",
    "Droit des sanctions internationales",
    "Droit de l’espace",
    "Droit des données ouvertes",
    "Droit de l’open source",
    "Droit des contrats publics",
    "Partenariats public-privé (PPP)",
    "Droit de la commande publique",
    "Droit des marchés publics",
    "Droit de la franchise",
    "Droit des réseaux de distribution",
    "Digitalisation juridique",
    "Automatisation des processus juridiques",
    "Legaltech",
    "Analyse prédictive juridique",
    "Gestion de projets juridiques",
    "Optimisation des processus juridiques",
    "Droit interculturel",
    "Droit comparé",
    "Droit de la gouvernance ESG"
],
        "Production & Logistique": [
    "Gestion de production",
    "Planification de la production",
    "Ordonnancement",
    "Gestion des capacités de production",
    "Optimisation des lignes de production",
    "Supply chain",
    "Gestion de la chaîne d’approvisionnement",
    "Coordination de la supply chain",
    "Achats",
    "Négociation avec les fournisseurs",
    "Sourcing stratégique",
    "Gestion des contrats d’achat",
    "Achats responsables",
    "Gestion des stocks",
    "Optimisation des stocks",
    "Inventaire physique",
    "Gestion des stocks JIT (Just-In-Time)",
    "Qualité",
    "Contrôle qualité",
    "Assurance qualité",
    "Normes ISO (9001, 14001, etc.)",
    "Lean management",
    "Lean manufacturing",
    "Kaizen",
    "Six Sigma",
    "Transport",
    "Gestion des flux de transport",
    "Optimisation des itinéraires",
    "Logistique du dernier kilomètre",
    "Logistique internationale",
    "Logistique inverse (retours)",
    "Logistique verte",
    "Logistique urbaine",
    "Entreposage",
    "Gestion d’entrepôts",
    "Automatisation des entrepôts",
    "WMS (Warehouse Management System)",
    "Cross-docking",
    "Gestion des flux logistiques",
    "Logistique événementielle",
    "Logistique humanitaire",
    "Logistique de projet",
    "Planification des besoins en matériel (MRP)",
    "ERP (Enterprise Resource Planning)",
    "Implémentation d’ERP (SAP, Oracle)",
    "Maintenance industrielle",
    "Maintenance préventive",
    "Maintenance prédictive",
    "GMAO (Gestion de Maintenance Assistée par Ordinateur)",
    "Gestion des équipements",
    "Gestion de la sécurité industrielle",
    "Sécurité des entrepôts",
    "Gestion des risques logistiques",
    "Analyse des risques supply chain",
    "Plan de continuité logistique",
    "Gestion des douanes",
    "Réglementation douanière",
    "Gestion des incoterms",
    "Logistique multimodale",
    "Transport maritime",
    "Transport aérien",
    "Transport ferroviaire",
    "Transport routier",
    "Gestion des flottes de véhicules",
    "Optimisation des coûts de transport",
    "Gestion des coûts logistiques",
    "Analyse des coûts de production",
    "Costing logistique",
    "Budgétisation logistique",
    "KPI logistiques",
    "Tableaux de bord logistiques",
    "Performance logistique",
    "Gestion de la demande",
    "Prévisions de la demande",
    "Demand planning",
    "Supply planning",
    "Gestion des fournisseurs",
    "Évaluation des fournisseurs",
    "Audit des fournisseurs",
    "Gestion des relations fournisseurs (SRM)",
    "Achats durables",
    "Supply chain durable",
    "Économie circulaire",
    "Logistique écoresponsable",
    "Réduction de l’empreinte carbone",
    "Gestion des déchets industriels",
    "Recyclage en logistique",
    "Automatisation de la production",
    "Robotisation industrielle",
    "Industrie 4.0",
    "IoT (Internet des Objets) en logistique",
    "Blockchain en supply chain",
    "Traçabilité des produits",
    "RFID (Radio Frequency Identification)",
    "Gestion des codes-barres",
    "Digitalisation de la logistique",
    "Digitalisation de la production",
    "Analyse prédictive logistique",
    "Analyse prédictive production",
    "Data analytics en supply chain",
    "Intelligence artificielle en logistique",
    "Machine learning en production",
    "Big Data en logistique",
    "Simulation logistique",
    "Simulation de production",
    "Planification avancée (APS)",
    "Gestion de projets logistiques",
    "Gestion de projets industriels",
    "Gestion des délais de production",
    "Gestion des retards logistiques",
    "Lean supply chain",
    "Agilité logistique",
    "Logistique collaborative",
    "Partenariats logistiques",
    "Externalisation logistique (3PL, 4PL)",
    "Gestion des sous-traitants",
    "Conformité réglementaire logistique",
    "Conformité sécurité alimentaire (HACCP)",
    "Conformité pharmaceutique",
    "Logistique pharmaceutique",
    "Logistique agroalimentaire",
    "Logistique du froid (chaîne du froid)",
    "Gestion des produits dangereux",
    "Logistique de produits volumineux",
    "Logistique des matières premières",
    "Gestion des emballages",
    "Optimisation des emballages",
    "Étiquetage logistique",
    "Gestion des retours clients",
    "Service client logistique",
    "Expérience client en logistique",
    "Veille technologique logistique",
    "Formation en logistique",
    "Formation en production",
    "Gestion des équipes logistiques",
    "Gestion des équipes de production",
    "Optimisation des processus logistiques",
    "Optimisation des processus de production",
    "Gestion des crises logistiques",
    "RSE (Responsabilité Sociétale des Entreprises) en logistique",
    "Gestion des audits logistiques",
    "Certification logistique",
    "Gestion multicanale logistique",
    "Logistique omnicanale",
    "Gestion des pics d’activité",
    "Flexibilité logistique",
    "Gestion des flux tendus"
],
        "Santé & Social": [
    "Soins médicaux",
    "Soins infirmiers",
    "Soins d’urgence",
    "Soins palliatifs",
    "Soins à domicile",
    "Accompagnement social",
    "Aide à la personne",
    "Accompagnement des personnes handicapées",
    "Accompagnement des personnes âgées",
    "Prévention",
    "Prévention des maladies",
    "Éducation à la santé",
    "Promotion de la santé",
    "Gestion d’établissement",
    "Administration hospitalière",
    "Gestion des EHPAD",
    "Santé publique",
    "Épidémiologie",
    "Politiques de santé publique",
    "Coordination d’équipe",
    "Gestion des équipes soignantes",
    "Supervision clinique",
    "Médecine",
    "Médecine générale",
    "Médecine spécialisée",
    "Chirurgie",
    "Anesthésie",
    "Radiologie",
    "Pharmacologie",
    "Médecine d’urgence",
    "Médecine du travail",
    "Médecine scolaire",
    "Médecine légale",
    "Médecine préventive",
    "Télémédecine",
    "Santé mentale",
    "Psychiatrie",
    "Psychologie clinique",
    "Thérapie comportementale",
    "Conseil en santé mentale",
    "Travail social",
    "Assistance sociale",
    "Médiation sociale",
    "Insertion sociale",
    "Aide aux familles",
    "Protection de l’enfance",
    "Protection des adultes vulnérables",
    "Soins pédiatriques",
    "Soins gériatriques",
    "Soins obstétriques",
    "Sage-femmerie",
    "Rééducation",
    "Kinésithérapie",
    "Ergothérapie",
    "Orthophonie",
    "Podologie",
    "Prothèses et orthèses",
    "Nutrition clinique",
    "Diététique",
    "Conseil en nutrition",
    "Gestion des risques sanitaires",
    "Hygiène hospitalière",
    "Contrôle des infections",
    "Sécurité des patients",
    "Qualité des soins",
    "Audit des pratiques médicales",
    "Certification des établissements de santé",
    "Gestion des données de santé",
    "Dossier patient électronique",
    "Conformité RGPD (santé)",
    "Cybersécurité en santé",
    "Recherche médicale",
    "Recherche clinique",
    "Biostatistique",
    "Éthique médicale",
    "Bioéthique",
    "Consentement éclairé",
    "Santé communautaire",
    "Médiation en santé",
    "Santé environnementale",
    "Santé au travail",
    "Prévention des risques professionnels",
    "Ergonomie",
    "Gestion des crises sanitaires",
    "Plan de continuité sanitaire",
    "Logistique médicale",
    "Gestion des approvisionnements médicaux",
    "Pharmacie hospitalière",
    "Gestion des médicaments",
    "Pharmacovigilance",
    "Soins dentaires",
    "Orthodontie",
    "Optométrie",
    "Audiologie",
    "Santé numérique",
    "Développement d’applications de santé",
    "IA en santé",
    "Analyse prédictive en santé",
    "Big Data en santé",
    "Dispositifs médicaux",
    "Maintenance des équipements médicaux",
    "Conception de dispositifs médicaux",
    "Santé connectée",
    "Objets connectés en santé",
    "Téléconsultation",
    "Télésoin",
    "Santé mobile (mHealth)",
    "Formation des soignants",
    "Formation continue en santé",
    "Simulation médicale",
    "Enseignement médical",
    "Communication en santé",
    "Relation patient-soignant",
    "Empathie dans les soins",
    "Accompagnement psychologique",
    "Soutien aux aidants",
    "Soins interculturels",
    "Santé des populations migrantes",
    "Santé des populations vulnérables",
    "Égalité d’accès aux soins",
    "Inclusion en santé",
    "Santé des femmes",
    "Santé des enfants",
    "Santé des LGBTQ+",
    "Prévention des addictions",
    "Lutte contre le tabagisme",
    "Prévention de l’obésité",
    "Vaccination",
    "Dépistage",
    "Gestion des programmes de dépistage",
    "Soins de longue durée",
    "Gestion des maladies chroniques",
    "Réadaptation",
    "Soins post-opératoires",
    "Soins intensifs",
    "Soins néonataux",
    "Santé vétérinaire",
    "Santé globale (One Health)",
    "Coopération internationale en santé",
    "Aide humanitaire médicale",
    "Gestion des ONG de santé",
    "Financement des établissements de santé",
    "Analyse économique en santé",
    "Évaluation des technologies de santé",
    "Gestion des ressources humaines en santé",
    "Recrutement en santé",
    "Planification des effectifs médicaux",
    "Bien-être des soignants",
    "Prévention du burn-out",
    "RSE (Responsabilité Sociétale des Entreprises) en santé",
    "Santé durable",
    "Réduction de l’empreinte carbone en santé",
    "Gestion des déchets médicaux",
    "Optimisation des processus de soins",
    "Lean management en santé",
    "Gestion de projets en santé",
    "Digitalisation des services de santé",
    "Veille réglementaire en santé",
    "Conformité aux normes sanitaires",
    "Audit sanitaire",
    "Gestion des litiges en santé",
    "Médiation en santé",
    "Droit de la santé",
    "Responsabilité médicale"
],
        "Éducation & Formation": [
    "Pédagogie",
    "Pédagogie active",
    "Pédagogie différenciée",
    "Pédagogie inclusive",
    "Pédagogie Montessori",
    "Pédagogie Freinet",
    "Animation de formation",
    "Animation de groupes",
    "Animation d’ateliers",
    "Ingénierie pédagogique",
    "Conception de programmes de formation",
    "Conception de modules e-learning",
    "Tutorat",
    "Accompagnement individuel",
    "Mentorat",
    "Enseignement",
    "Enseignement primaire",
    "Enseignement secondaire",
    "Enseignement supérieur",
    "Enseignement professionnel",
    "Enseignement spécialisé",
    "Évaluation",
    "Évaluation des compétences",
    "Évaluation formative",
    "Évaluation sommative",
    "Conception d’outils d’évaluation",
    "Coordination",
    "Coordination pédagogique",
    "Coordination d’équipes éducatives",
    "Gestion de projets éducatifs",
    "Développement de curriculum",
    "Adaptation des programmes éducatifs",
    "Formation continue",
    "Formation professionnelle",
    "Formation pour adultes",
    "Formation en entreprise",
    "Formation à distance",
    "Blended learning",
    "Microlearning",
    "Gamification pédagogique",
    "Classe inversée",
    "Apprentissage collaboratif",
    "Apprentissage par projet",
    "Apprentissage expérientiel",
    "Apprentissage par compétences",
    "Enseignement bilingue",
    "Enseignement multilingue",
    "Éducation interculturelle",
    "Éducation inclusive",
    "Éducation spécialisée",
    "Soutien scolaire",
    "Remédiation pédagogique",
    "Accompagnement des troubles d’apprentissage",
    "Gestion des élèves à besoins spécifiques",
    "Éducation à la citoyenneté",
    "Éducation aux médias",
    "Édition d’art",
    "Édition numérique",
    "Correction de textes",
    "Maquette et mise en page",
    "Gestion de projet culturel",
    "Planification d’événements culturels",
    "Budgétisation culturelle",
    "Programmation",
    "Programmation de festivals",
    "Programmation de saisons culturelles",
    "Curation",
    "Commissariat d’exposition",
    "Scénographie",
    "Design d’exposition",
    "Conservation du patrimoine",
    "Restauration d’œuvres d’art",
    "Gestion de musées",
    "Gestion de galeries",
    "Gestion d’archives culturelles",
    "Catalogage patrimonial",
    "Numérisation du patrimoine",
    "Artisanat d’art",
    "Ébénisterie",
    "Orfèvrerie",
    "Vitrail",
    "Mosaïque",
    "Performance artistique",
    "Danse contemporaine",
    "Danse classique",
    "Chorégraphie",
    "Théâtre",
    "Mise en scène",
    "Écriture dramatique",
    "Musique",
    "Composition musicale",
    "Interprétation musicale",
    "Direction d’orchestre",
    "Ingénierie du son",
    "Design sonore",
    "Cinéma",
    "Réalisation de films",
    "Scénarisation",
    "Montage vidéo",
    "Effets spéciaux (VFX)",
    "Animation 2D",
    "Animation 3D",
    "Art interactif",
    "Art immersif",
    "Réalité augmentée (AR) artistique",
    "Réalité virtuelle (VR) artistique",
    "Art dans le métavers",
    "Design graphique",
    "Illustration",
    "Typographie",
    "Motion design",
    "Webdesign culturel",
    "UX/UI pour projets culturels",
    "Communication culturelle",
    "Marketing culturel",
    "Stratégie de communication culturelle",
    "Gestion des réseaux sociaux culturels",
    "Relations presse culturelles",
    "Crowdfunding culturel",
    "Mécénat",
    "Sponsoring culturel",
    "Fundraising culturel",
    "Gestion des droits d’auteur",
    "Droit de la propriété intellectuelle",
    "Contrats artistiques",
    "Fiscalité culturelle",
    "Gestion des bénévoles culturels",
    "Coordination d’équipes artistiques",
    "Formation artistique",
    "Enseignement des arts",
    "Ateliers d’art-thérapie",
    "Médiation artistique",
    "Éducation à la culture",
    "Gestion des publics culturels",
    "Accessibilité culturelle",
    "Inclusion culturelle",
    "Programmes culturels pour publics vulnérables",
    "Culture et diversité",
    "Patrimoine immatériel",
    "Ethnographie culturelle",
    "Recherche en histoire de l’art",
    "Critique d’art",
    "Journalisme culturel",
    "Écriture culturelle",
    "Blogging culturel",
    "Création de podcasts culturels",
    "Vidéos culturelles",
    "Live streaming culturel",
    "Gestion de festivals",
    "Organisation de biennales",
    "Gestion de résidences d’artistes",
    "Programmes d’échange culturel",
    "Diplomatie culturelle",
    "Coopération culturelle internationale",
    "Gestion des subventions culturelles",
    "Évaluation des projets culturels",
    "RSE (Responsabilité Sociétale des Entreprises) culturelle",
    "Culture durable",
    "Écoconception culturelle",
    "Gestion des déchets culturels",
    "Numérisation des œuvres",
    "Blockchain pour l’art",
    "NFT (Non-Fungible Tokens) artistiques",
    "IA dans la création artistique",
    "Analyse prédictive culturelle",
    "Big Data culturel",
    "Gestion de bases de données culturelles",
    "Conformité RGPD (culture)",
    "Cybersécurité culturelle",
    "Veille culturelle",
    "Tendances culturelles",
    "Innovation culturelle",
    "Gestion des crises culturelles",
    "Plan de continuité culturelle",
    "Culture en contexte de crise",
    "Gestion des équipements culturels",
    "Sécurité des lieux culturels",
    "Gestion des collections",
    "Prêt d’œuvres d’art",
    "Transport d’œuvres d’art",
    "Assurance des œuvres d’art",
    "Évaluation des œuvres d’art",
    "Marché de l’art",
    "Vente aux enchères",
    "Expertise artistique",
    "Gestion des communautés culturelles",
    "Animation de communautés artistiques",
    "Culture participative",
    "Co-création artistique",
    "Gestion de projets interculturels",
    "Traduction culturelle",
    "Localisation culturelle",
    "Gestion des droits culturels"
],

        # Compétences transversales
        "Langues": ["Anglais", "Espagnol", "Allemand", "Italien", "Chinois", "Arabe", "Russe", "Portugais", "Japonais"],
        "Outils bureautiques": [
    "Suite Office",
    "Microsoft Word",
    "Création de documents Word",
    "Mise en forme avancée Word",
    "Modèles Word",
    "Fusion et publipostage Word",
    "Microsoft Excel",
    "Création de tableaux Excel",
    "Formules et fonctions Excel",
    "Tableaux croisés dynamiques",
    "Macros Excel",
    "Visualisation de données Excel",
    "Microsoft PowerPoint",
    "Création de présentations PowerPoint",
    "Design de diapositives",
    "Transitions et animations PowerPoint",
    "Modèles PowerPoint",
    "Microsoft Outlook",
    "Gestion des e-mails Outlook",
    "Planification de réunions Outlook",
    "Gestion des tâches Outlook",
    "Gestion des contacts Outlook",
    "Microsoft Access",
    "Création de bases de données Access",
    "Requêtes Access",
    "Formulaires et rapports Access",
    "Microsoft OneNote",
    "Prise de notes OneNote",
    "Organisation de notes OneNote",
    "Partage de notes OneNote",
    "Google Workspace",
    "Google Docs",
    "Création de documents Google Docs",
    "Collaboration en temps réel Google Docs",
    "Google Sheets",
    "Analyse de données Google Sheets",
    "Scripts Google Apps Script",
    "Google Slides",
    "Création de présentations Google Slides",
    "Google Drive",
    "Gestion de fichiers Google Drive",
    "Partage de fichiers Google Drive",
    "Google Forms",
    "Création de formulaires Google Forms",
    "Analyse des réponses Google Forms",
    "Google Calendar",
    "Planification Google Calendar",
    "Gestion des événements Google Calendar",
    "Google Meet",
    "Animation de réunions Google Meet",
    "Gestion des paramètres Google Meet",
    "Microsoft 365",
    "Microsoft Teams",
    "Collaboration via Microsoft Teams",
    "Gestion des canaux Teams",
    "Organisation de réunions Teams",
    "Microsoft SharePoint",
    "Création de sites SharePoint",
    "Gestion de contenu SharePoint",
    "Microsoft Power BI",
    "Création de tableaux de bord Power BI",
    "Analyse de données Power BI",
    "Microsoft Power Automate",
    "Automatisation des flux Power Automate",
    "Microsoft Power Apps",
    "Développement d’applications Power Apps",
    "Outils collaboratifs",
    "Slack",
    "Gestion des communications Slack",
    "Intégrations Slack",
    "Trello",
    "Gestion de projets Trello",
    "Création de tableaux Trello",
    "Asana",
    "Planification de tâches Asana",
    "Suivi de projets Asana",
    "Notion",
    "Organisation de projets Notion",
    "Création de bases de données Notion",
    "Zoom",
    "Animation de réunions Zoom",
    "Gestion des webinaires Zoom",
    "Gestion documentaire",
    "Archivage numérique",
    "Numérisation de documents",
    "Gestion des métadonnées",
    "GED (Gestion Électronique des Documents)",
    "Utilisation de DocuSign",
    "Signature électronique",
    "Adobe Acrobat",
    "Édition de PDF Acrobat",
    "Annotation de PDF Acrobat",
    "Conversion de fichiers Acrobat",
    "Evernote",
    "Prise de notes Evernote",
    "Organisation de notes Evernote",
    "Monday.com",
    "Gestion de projets Monday.com",
    "Automatisation Monday.com",
    "Miro",
    "Création de tableaux blancs Miro",
    "Collaboration visuelle Miro",
    "Airtable",
    "Création de bases Airtable",
    "Gestion de projets Airtable",
    "ClickUp",
    "Planification de tâches ClickUp",
    "Suivi de projets ClickUp",
    "Zoho Suite",
    "Zoho Docs",
    "Zoho CRM",
    "Zoho Projects",
    "LibreOffice",
    "LibreOffice Writer",
    "LibreOffice Calc",
    "LibreOffice Impress",
    "Gestion des versions de documents",
    "Synchronisation des fichiers",
    "Sécurité des documents",
    "Conformité RGPD (bureautique)",
    "Cybersécurité bureautique",
    "Automatisation des tâches bureautiques",
    "Scripting bureautique",
    "Intégration d’outils bureautiques",
    "Personnalisation des outils bureautiques",
    "Formation aux outils bureautiques",
    "Support utilisateur bureautique",
    "Migration vers le cloud bureautique",
    "Gestion des licences bureautiques",
    "Optimisation des processus bureautiques",
    "Analyse de données bureautiques",
    "Création de rapports bureautiques",
    "Gestion des tâches collaboratives",
    "Planification collaborative",
    "Gestion des flux de travail",
    "Accessibilité numérique bureautique",
    "Utilisation de raccourcis clavier",
    "Personnalisation des interfaces bureautiques",
    "Gestion des modèles bureautiques",
    "Création de formulaires interactifs",
    "Gestion des bases de données bureautiques",
    "Utilisation de plugins bureautiques",
    "Gestion des sauvegardes bureautiques",
    "Récupération de données bureautiques",
    "Utilisation d’outils de prise de notes collaboratives",
    "Gestion des projets bureautiques",
    "Veille sur les outils bureautiques",
    "Évaluation des outils bureautiques",
    "Intégration avec des outils tiers"
],
        "Gestion de projet": [
    "Méthodologie agile",
    "Scrum",
    "Kanban",
    "SAFe (Scaled Agile Framework)",
    "Lean project management",
    "PRINCE2",
    "PMI (Project Management Institute)",
    "PMP (Project Management Professional)",
    "CAPM (Certified Associate in Project Management)",
    "Planification",
    "Élaboration de plannings",
    "Diagrammes de Gantt",
    "PERT (Program Evaluation and Review Technique)",
    "Critical Path Method (CPM)",
    "Gestion des ressources",
    "Allocation des ressources",
    "Planification des capacités",
    "Gestion des risques",
    "Identification des risques",
    "Analyse qualitative des risques",
    "Analyse quantitative des risques",
    "Plan de mitigation des risques",
    "Gestion des imprévus",
    "Gestion budgétaire",
    "Élaboration de budgets",
    "Suivi des coûts",
    "Analyse des écarts budgétaires",
    "Cost control",
    "Reporting",
    "Création de rapports de projet",
    "Tableaux de bord de projet",
    "Reporting exécutif",
    "KPI (Key Performance Indicators) de projet",
    "Gestion des parties prenantes",
    "Cartographie des parties prenantes",
    "Engagement des parties prenantes",
    "Négociation avec les parties prenantes",
    "Communication de projet",
    "Plan de communication",
    "Animation de réunions",
    "Présentations de projet",
    "Gestion d’équipe",
    "Leadership d’équipe",
    "Motivation d’équipe",
    "Résolution de conflits d’équipe",
    "Coaching d’équipe",
    "Gestion du changement",
    "Plan de gestion du changement",
    "Accompagnement au changement",
    "Adoption des changements",
    "Gestion des livrables",
    "Définition des livrables",
    "Suivi des livrables",
    "Validation des livrables",
    "Gestion de la qualité",
    "Contrôle qualité",
    "Assurance qualité",
    "Normes de qualité (ISO 9001)",
    "Gestion des délais",
    "Suivi des jalons",
    "Gestion des retards",
    "Optimisation des délais",
    "Gestion des contrats",
    "Négociation de contrats",
    "Suivi des contrats",
    "Gestion des sous-traitants",
    "Gestion des fournisseurs",
    "Évaluation des fournisseurs",
    "Gestion des appels d’offres",
    "Gestion de portefeuille de projets",
    "Priorisation des projets",
    "Gestion de programmes",
    "Alignement stratégique des projets",
    "Gestion multi-projets",
    "Gestion de projets internationaux",
    "Gestion interculturelle",
    "Gestion de projets virtuels",
    "Gestion de projets à distance",
    "Outils de gestion de projet",
    "Microsoft Project",
    "Primavera",
    "Jira",
    "Trello",
    "Asana",
    "Monday.com",
    "Smartsheet",
    "Gestion de projets avec ERP",
    "Automatisation des processus de projet",
    "Intégration d’outils de projet",
    "Gestion des données de projet",
    "Conformité RGPD (gestion de projet)",
    "Cybersécurité des projets",
    "Gestion des bases de connaissances",
    "Documentation de projet",
    "Archivage de projet",
    "Gestion des leçons apprises",
    "Retour d’expérience (REX)",
    "Gestion des crises de projet",
    "Plan de continuité de projet",
    "Gestion des imprévus critiques",
    "Gestion de projets agiles hybrides",
    "DevOps dans la gestion de projet",
    "Gestion de projets en cascade",
    "Gestion de projets itératifs",
    "Gestion de projets adaptatifs",
    "Gestion de projets complexes",
    "Gestion de projets à haute visibilité",
    "Gestion de projets à faible budget",
    "Gestion de projets innovants",
    "Gestion de projets R&D",
    "Gestion de projets de transformation",
    "Gestion de projets digitaux",
    "Gestion de projets de construction",
    "Gestion de projets événementiels",
    "Gestion de projets humanitaires",
    "Gestion de projets de développement durable",
    "RSE (Responsabilité Sociétale des Entreprises) dans les projets",
    "Gestion de projets ESG",
    "Gestion de projets culturels",
    "Gestion de projets éducatifs",
    "Gestion de projets de santé",
    "Analyse prédictive des projets",
    "IA dans la gestion de projet",
    "Big Data en gestion de projet",
    "Simulation de projet",
    "Planification avancée",
    "Optimisation des processus de projet",
    "Lean Six Sigma dans les projets",
    "Gestion des parties prenantes virtuelles",
    "Facilitation de workshops",
    "Gestion des sprints",
    "Animation de rétrospectives",
    "Gestion des backlogs",
    "Story mapping",
    "Gestion des dépendances entre projets",
    "Gestion des interdépendances",
    "Veille méthodologique",
    "Formation en gestion de projet",
    "Certification agile (Scrum Master, Product Owner)",
    "Certification PRINCE2 Practitioner",
    "Coaching en gestion de projet",
    "Mentoring de chefs de projet",
    "Évaluation des performances de projet",
    "Audit de projet",
    "Gestion des contrats agiles",
    "Gestion des budgets agiles",
    "Gestion des portefeuilles agiles",
    "Gestion de projets collaboratifs",
    "Gestion des projets open source",
    "Gestion des projets à impact social"
],
        "Soft skills": [
    "Communication",
    "Communication verbale",
    "Communication non verbale",
    "Communication écrite",
    "Écoute active",
    "Communication interculturelle",
    "Communication persuasive",
    "Présentation orale",
    "Storytelling",
    "Communication assertive",
    "Travail en équipe",
    "Collaboration",
    "Coordination d’équipe",
    "Esprit d’équipe",
    "Gestion des dynamiques de groupe",
    "Travail collaboratif à distance",
    "Résolution de problèmes",
    "Analyse critique",
    "Pensée analytique",
    "Résolution de problèmes complexes",
    "Prise de perspective",
    "Troubleshooting",
    "Créativité",
    "Pensée créative",
    "Innovation",
    "Brainstorming",
    "Design thinking",
    "Imagination",
    "Adaptabilité",
    "Flexibilité",
    "Résilience",
    "Gestion du changement",
    "Adaptation au stress",
    "Ouverture au changement",
    "Organisation",
    "Gestion du temps",
    "Planification",
    "Priorisation des tâches",
    "Gestion des délais",
    "Structuration des processus",
    "Leadership",
    "Leadership transformationnel",
    "Leadership situationnel",
    "Leadership collaboratif",
    "Leadership éthique",
    "Inspiration d’équipe",
    "Vision stratégique",
    "Négociation",
    "Négociation collaborative",
    "Négociation compétitive",
    "Médiation",
    "Gestion des conflits",
    "Persuasion",
    "Gestion du stress",
    "Régulation émotionnelle",
    "Résistance à la pression",
    "Techniques de relaxation",
    "Mindfulness",
    "Prise de décision",
    "Prise de décision stratégique",
    "Prise de décision sous pression",
    "Évaluation des options",
    "Jugement critique",
    "Empathie",
    "Intelligence émotionnelle",
    "Compréhension des émotions",
    "Gestion des relations interpersonnelles",
    "Sensibilité culturelle",
    "Esprit critique",
    "Questionnement",
    "Évaluation des informations",
    "Pensée logique",
    "Attention aux détails",
    "Proactivité",
    "Initiative",
    "Anticipation",
    "Autonomie",
    "Responsabilité",
    "Fiabilité",
    "Persévérance",
    "Détermination",
    "Motivation intrinsèque",
    "Confiance en soi",
    "Estime de soi",
    "Authenticité",
    "Intégrité",
    "Éthique professionnelle",
    "Sens des valeurs",
    "Capacité d’apprentissage",
    "Apprentissage continu",
    "Curiosité intellectuelle",
    "Ouverture d’esprit",
    "Gestion de la diversité",
    "Inclusion",
    "Respect des différences",
    "Travail en environnement multiculturel",
    "Influence",
    "Capacité à motiver",
    "Charisme",
    "Gestion des parties prenantes",
    "Networking",
    "Construction de relations",
    "Mentorat",
    "Coaching",
    "Feedback constructif",
    "Donner du feedback",
    "Recevoir du feedback",
    "Capacité d’adaptation numérique",
    "Maîtrise des outils collaboratifs",
    "Agilité digitale",
    "Gestion des priorités",
    "Délégation",
    "Supervision",
    "Capacité à inspirer la confiance",
    "Fiabilité relationnelle",
    "Sens de l’humour",
    "Positivité",
    "Gestion des émotions en public",
    "Diplomatie",
    "Tact",
    "Capacité à synthétiser",
    "Clarté dans l’expression",
    "Gestion des réunions",
    "Facilitation de groupes",
    "Animation de workshops",
    "Résolution de crises relationnelles",
    "Capacité à rester calme",
    "Patience",
    "Tolérance",
    "Capacité à gérer l’ambiguïté",
    "Prise d’initiative stratégique",
    "Sens de l’observation",
    "Capacité à identifier les besoins",
    "Sens du service",
    "Orientation client",
    "Capacité à travailler sous pression",
    "Gestion des imprévus",
    "Flexibilité cognitive",
    "Capacité à apprendre de ses erreurs",
    "Auto-évaluation",
    "Réflexivité",
    "Sens de la responsabilité sociale",
    "Engagement communautaire",
    "Capacité à collaborer virtuellement",
    "Gestion du télétravail",
    "Capacité à maintenir la motivation à distance"
]
    }

    # Choisir 3-5 catégories pertinentes
    categories_selected = random.sample(list(competences_categories_generales.keys()), random.randint(3, 5))

    competences_text = "Compétences\n"
    competences_entities = []

    # Pour chaque catégorie, sélectionner des compétences
    for categorie in categories_selected:
        comp_list = competences_categories_generales[categorie]
        # Sélectionner quelques compétences aléatoires de cette catégorie
        selected_comps = random.sample(comp_list, random.randint(2, min(len(comp_list), 5)))

        # Varier le format de présentation
        format_type = random.randint(1, 3)
        if format_type == 1:
            comp_str = f"• {categorie} : {', '.join(selected_comps)}\n"
        elif format_type == 2:
            comp_str = f"{categorie}\n" + "".join([f"  - {comp}\n" for comp in selected_comps])
        else:
            comp_str = f"• {categorie}\n" + "".join([f"  ✓ {comp}\n" for comp in selected_comps])

        competences_text += comp_str

        # Ajouter chaque compétence comme une entité
        for comp in selected_comps:
            start_comp = competences_text.find(comp)
            if start_comp != -1:  # S'assurer que la compétence est trouvée
                competences_entities.append((start_comp, start_comp + len(comp), "COMPETENCE"))

    # Ajouter parfois une section sur les langues et/ou les centres d'intérêt
    sections_additionnelles = []

    if random.choice([True, False, False]):  # 1/3 chance
        langues = [
            ("Français", "Langue maternelle"),
            ("Anglais", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"])),
            ("Espagnol", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"])),
            ("Allemand", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"])),
            ("Italien", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"])),
            ("Arabe", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"])),
            ("Chinois", random.choice(["Courant", "Intermédiaire", "Bilingue", "Notions", "Niveau C1", "Niveau B2"]))
        ]

        selected_langues = random.sample(langues, random.randint(2, 4))

        langues_text = "Langues\n"
        for langue, niveau in selected_langues:
            format_type = random.randint(1, 3)
            if format_type == 1:
                langues_text += f"• {langue} : {niveau}\n"
            elif format_type == 2:
                langues_text += f"- {langue} ({niveau})\n"
            else:
                langues_text += f"{langue} : {niveau}\n"

        sections_additionnelles.append(langues_text)

    if random.choice([True, False, False]):  # 1/3 chance
        interets = [
            "Sports", "Voyages", "Photographie", "Musique", "Littérature", "Cinéma",
            "Art", "Cuisine", "Jardinage", "Bricolage", "Randonnée", "Plongée",
            "Équitation", "Yoga", "Méditation", "Jeux de société", "Échecs", "Bénévolat",
            "Théâtre", "Danse", "Astronomie", "Histoire", "Technologie", "Sports mécaniques"
        ]

        selected_interets = random.sample(interets, random.randint(2, 5))

        format_type = random.randint(1, 3)
        if format_type == 1:
            interets_text = "Centres d'intérêt\n• " + "\n• ".join(selected_interets) + "\n"
        elif format_type == 2:
            interets_text = "Loisirs\n- " + "\n- ".join(selected_interets) + "\n"
        else:
            interets_text = "Intérêts\n" + ", ".join(selected_interets) + "\n"

        sections_additionnelles.append(interets_text)

    # Construction du CV complet
    texte = f"{nom}\nEmail : {email}\nTél : {telephone}\nAdresse : {adresse}\n\n"

    # Création des entités de base avec leur position dans le texte final
    entities = []
    entities.append((0, len(nom), "NOM"))
    entities.append((texte.find(email), texte.find(email) + len(email), "EMAIL"))
    entities.append((texte.find(telephone), texte.find(telephone) + len(telephone), "TELEPHONE"))
    entities.append((texte.find(adresse), texte.find(adresse) + len(adresse), "ADRESSE"))

    # Mémoriser la longueur actuelle du texte avant d'ajouter chaque section
    position_actuelle = len(texte)

    # Ajouter le profil et mettre à jour la position
    texte += profil
    position_profil = position_actuelle
    position_actuelle = len(texte)

    # Ajouter la section formation
    section_formation = formations_text
    texte += section_formation

    # Calculer le décalage pour les entités de formation
    for formation_entity in formations_entities:
        start, end, label = formation_entity
        # Calculer les nouvelles positions en ajoutant le décalage de la section
        new_start = position_actuelle + start
        new_end = position_actuelle + end
        entities.append((new_start, new_end, label))

    # Mettre à jour la position actuelle
    position_actuelle = len(texte)

    # Ajouter la section expérience professionnelle
    section_experience = experience_text
    texte += section_experience

    # Calculer le décalage pour les entités d'expérience
    for exp_entity in experience_entities:
        start, end, label = exp_entity
        # Calculer les nouvelles positions
        new_start = position_actuelle + start
        new_end = position_actuelle + end
        entities.append((new_start, new_end, label))

    # Mettre à jour la position actuelle
    position_actuelle = len(texte)

    # Ajouter la section compétences
    section_competences = competences_text
    texte += section_competences

    # Calculer le décalage pour les entités de compétences
    for comp_entity in competences_entities:
        start, end, label = comp_entity
        # Calculer les nouvelles positions
        new_start = position_actuelle + start
        new_end = position_actuelle + end
        entities.append((new_start, new_end, label))

    # Mettre à jour la position actuelle
    position_actuelle = len(texte)

    # Ajouter les sections additionnelles
    for section in sections_additionnelles:
        # On peut ajouter ici le traitement des entités pour ces sections si nécessaire
        texte += "\n" + section
        position_actuelle = len(texte)

    # Vérification finale des entités
    entities_validees = []
    for start, end, label in entities:
        # S'assurer que les positions sont valides
        if start < end and end <= len(texte):
            entity_text = texte[start:end]
            # Vérifier que l'entité est bien ce qu'on pense
            entities_validees.append((start, end, label))
        else:
            print(f"Position invalide détectée: {start}:{end} pour '{label}'")

    return texte, {"entities": entities_validees}

# Générer les données
cv_data = [generer_cv_avance() for _ in range(5000)]
train_data, test_data = train_test_split(cv_data, test_size=0.2)

# Sauvegarde au format spaCy
def save_data(data, output_path):
    nlp = spacy.blank("fr")
    db = DocBin()

    for text, annot in data:
        doc = nlp.make_doc(text)
        ents = []
        seen_tokens = set()

        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is not None and not any(tok.i in seen_tokens for tok in span):
                ents.append(span)
                seen_tokens.update(tok.i for tok in span)

        doc.ents = ents
        db.add(doc)

    db.to_disk(output_path)


save_data(train_data, "train.spacy")
save_data(test_data, "test.spacy")

# %%
# !python -m spacy train /content/config.cfg --output ./output --paths.train /content/train.spacy --paths.dev /content/test.spacy --gpu-id 0
